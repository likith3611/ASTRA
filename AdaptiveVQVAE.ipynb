# %%
import torch
import numpy as np
from scenarionet import read_dataset_summary, read_scenario
from metadrive.engine.asset_loader import AssetLoader
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
from torch.utils.data import DataLoader
from torch_geometric.nn import GCNConv, GATConv
from torch_geometric.data import Data, Batch

# %%
# %env CUDA_LAUNCH_BLOCKING=1
# Out:
# env: CUDA_LAUNCH_BLOCKING=1

# %%
torch.cuda.empty_cache()

# %%
av2_data =  AssetLoader.file_path("/home/light/Documents/Thesis/preprocessed_dataset", unix_style=False)
dataset_summary, scenario_ids, mapping = read_dataset_summary(dataset_path=av2_data)

scenario_file_name = scenario_ids[0]
scenario = read_scenario(dataset_path=av2_data, mapping=mapping, scenario_file_name=scenario_file_name)
scenario.keys()
# Out:
# dict_keys(['id', 'version', 'length', 'tracks', 'dynamic_map_states', 'map_features', 'metadata'])

# %%
import torch
import numpy as np

class AdaptiveTokenScenarioNet:
    def __init__(self, importance_threshold=0.5, max_tokens=512, token_length=10, use_gpu=False):
        self.importance_threshold = importance_threshold
        self.max_tokens = max_tokens
        self.token_length = token_length
        self.device = torch.device('cuda' if (use_gpu and torch.cuda.is_available()) else 'cpu')
        self.type_importance = {
            'VEHICLE': 1.0,
            'PEDESTRIAN': 0.8,
            'BICYCLE': 0.7,
            'STATIC': 0.5,
            'UNKNOWN': 0.3
        }
        self.map_feature_importance = {
            'LANE': 0.9,
            'CROSSWALK': 0.7,
            'STOP_SIGN': 0.6,
            'TRAFFIC_LIGHT': 0.8,
            'UNKNOWN': 0.4
        }
        # Need to check these scores whether its proper or should I turn this to a hyperparameter learning patameter would be super costly

    def score_tracks(self, tracks):
        importance_scores = {}
        for track_id, track in tracks.items():
            state = track['state']
            valid = state['valid']
            if not valid.any():
                importance_scores[track_id] = 0
                continue
            positions = state['position'][valid]
            velocities = state['velocity'][valid]
            headings = state['heading'][valid]
            lengths = state['length'][valid]
            widths = state['width'][valid]
            heights = state['height'][valid]
            activity_score = np.linalg.norm(positions, axis=1).sum()
            velocity_score = np.linalg.norm(velocities, axis=1).sum()
            heading_score = np.abs(headings).sum()
            size_score = lengths.sum() + widths.sum() + heights.sum()
            type_score = self.type_importance.get(track.get('type', 'UNKNOWN'), 0.3)
            importance_scores[track_id] = activity_score + velocity_score + heading_score + size_score + type_score
            # No dynamic map features and the logic for importance score needs to be verified and should I normalise the dtaa here
        return importance_scores

    def score_map_features(self, map_features):
        importance_scores = {}
        for feature_id, feature in map_features.items():
            feature_type = feature.get('type', 'UNKNOWN')
            polyline = feature.get('polyline', [])
            if len(polyline) == 0:
                importance_scores[feature_id] = 0
                continue
            feature_score = len(polyline) * self.map_feature_importance.get(feature_type, 0.4)
            importance_scores[feature_id] = feature_score
        return importance_scores

    def pad_or_truncate(self, token, expected_dim):
        if token.shape[1] != expected_dim:
            token = token[:, :expected_dim] if token.shape[1] > expected_dim else np.pad(
                token, ((0, 0), (0, expected_dim - token.shape[1])), mode='constant'
            )
        if token.shape[0] > self.token_length:
            token = token[:self.token_length]
        else:
            pad_length = self.token_length - token.shape[0]
            pad = np.zeros((pad_length, expected_dim), dtype=np.float32)
            token = np.vstack((token, pad))
        return token

    def tokenize_tracks(self, tracks):
        tokenized_tracks = {}
        for track_id, track in tracks.items():
            state = track['state']
            valid = state['valid']
            if not valid.any():
                tokenized_tracks[track_id] = torch.empty((self.token_length, 9), dtype=torch.float32, device=self.device)
                continue
            positions = state['position'][valid]
            velocities = state['velocity'][valid]
            headings = state['heading'][valid]
            lengths = state['length'][valid]
            widths = state['width'][valid]
            heights = state['height'][valid]
            combined_token = np.column_stack((positions, velocities, headings, lengths, widths, heights))
            token = self.pad_or_truncate(combined_token, expected_dim=9)
            tokenized_tracks[track_id] = torch.tensor(token, dtype=torch.float32, device=self.device)
        return tokenized_tracks

    def tokenize_map_features(self, map_features):
        tokenized_features = {}
        for feature_id, feature in map_features.items():
            polyline = feature.get('polyline', [])
            if len(polyline) == 0:
                tokenized_features[feature_id] = torch.empty((self.token_length, 2), dtype=torch.float32, device=self.device)
                continue
            polyline_array = np.array(polyline)
            polyline_array = polyline_array[:, :2] if polyline_array.shape[1] > 2 else polyline_array
            token = self.pad_or_truncate(polyline_array, expected_dim=2)
            tokenized_features[feature_id] = torch.tensor(token, dtype=torch.float32, device=self.device)
            # Currently just added polyline need to check left right neighbours and need to still properluy sturcture also need to add boundary
            # Traffic info is not available
        return tokenized_features

    def process(self, scenario):
        tracks = scenario.get('tracks', {})
        map_features = scenario.get('map_features', {})
        metadata = scenario.get('metadata', {})
        track_scores = self.score_tracks(tracks)
        map_scores = self.score_map_features(map_features)
        tokenized_tracks = self.tokenize_tracks(tracks)
        tokenized_map_features = self.tokenize_map_features(map_features)
        for track_id, track in tracks.items():
            track['importance_score'] = track_scores[track_id]
            track['token'] = tokenized_tracks[track_id]
        for feature_id, feature in map_features.items():
            feature['importance_score'] = map_scores[feature_id]
            feature['token'] = tokenized_map_features[feature_id]
        scenario['tracks'] = tracks
        scenario['map_features'] = map_features
        return scenario

# %%
# scenarios = [
#     {
#         'id': 'scenario_1',
#         'version': 1,
#         'length': 10,
#         'tracks': {
#             'track_1': {'state': {'position': np.random.rand(10, 3), 'velocity': np.random.rand(10, 2), 
#                                   'heading': np.random.rand(10), 'length': np.random.rand(10), 
#                                   'width': np.random.rand(10), 'height': np.random.rand(10), 
#                                   'valid': np.array([True] * 10), 'type': 'VEHICLE'
#                                   }
#                                   }
#         },
#         'map_features': {
#             'lane_1': {'type': 'LANE', 'polyline': np.random.rand(10, 2)}
#         },
#         'metadata': {'scenario_id': 'sample_001', 'map': 'city_map_1'}
#     }
# ]
tokenizer = AdaptiveTokenScenarioNet(token_length=10, use_gpu=True)
tokens = tokenizer.process(scenario)

# %%
def custom_collate_fn(batch):
    batch_data = {'tracks': [], 'map_features': [], 'edge_index': []}
    for scenario in batch:
        if 'tracks' in scenario and 'map_features' in scenario:
            track_tokens = [t['token'] for t in scenario['tracks'].values()]
            map_tokens = [m['token'] for m in scenario['map_features'].values()]
            #Adding dummy edge_index for now latere need to write a logic to extract the data from the scenario, I am thinking idwise a->b->c->d and vice versa
            edge_index = scenario.get('edge_index', torch.empty((2, 0), dtype=torch.long))
            batch_data['tracks'].append(torch.stack(track_tokens))
            batch_data['map_features'].append(torch.stack(map_tokens))
            batch_data['edge_index'].append(edge_index)
    batch_data['tracks'] = torch.cat(batch_data['tracks'], dim=0) if batch_data['tracks'] else torch.empty(0)
    batch_data['map_features'] = torch.cat(batch_data['map_features'], dim=0) if batch_data['map_features'] else torch.empty(0)
    batch_data['edge_index'] = torch.cat(batch_data['edge_index'], dim=1) if batch_data['edge_index'] else torch.empty((2, 0), dtype=torch.long)
    return batch_data


class AVQVAE(nn.Module):
    def __init__(self, lr=1e-2, epochs=2000, commitment_loss_weight=0.1, device='cuda'):
        super(AVQVAE, self).__init__()
        self.device = torch.device(device if torch.cuda.is_available() else 'cpu')
        self.track_encoder = nn.Sequential(nn.Linear(9, 256), nn.LayerNorm(256), nn.ReLU(), nn.Dropout(0.2), nn.Linear(256, 256), nn.LayerNorm(256), nn.ReLU(), nn.Dropout(0.2),
            nn.TransformerEncoder( nn.TransformerEncoderLayer(d_model=256, nhead=2, dim_feedforward=256, dropout=0.2), num_layers=6),
            nn.Linear(256, 256), nn.LayerNorm(256), nn.ReLU())
        self.map_encoder_gnn = GCNConv(2, 256)
        self.map_encoder_post = nn.Sequential(nn.LayerNorm(256), nn.ReLU(), nn.Dropout(0.2))
        self.codebook = nn.Embedding(256, 256)
        self.track_decoder = nn.Sequential(nn.Linear(256, 256), nn.LayerNorm(256),nn.ReLU(),nn.Dropout(0.2), nn.Linear(256, 256),nn.LayerNorm(256),nn.ReLU(),nn.Linear(256, 9))
        self.map_decoder = nn.Sequential(nn.Linear(256, 256), nn.LayerNorm(256), nn.ReLU(), nn.Dropout(0.2), nn.Linear(256, 256), nn.LayerNorm(256), nn.ReLU(), nn.Linear(256, 2))
        # GAT is not possible because av2 scenarionet doesnt proivide dynamic map details its empty
        self.epochs = epochs
        self.optimizer = optim.AdamW(self.parameters(), lr=lr)
        self.commitment_loss_weight = commitment_loss_weight
        self.reconstruction_loss = nn.SmoothL1Loss()
        self.to(self.device)
    
    def forward(self, track_tokens, map_tokens, edge_index):
        track_tokens = track_tokens.to(self.device)
        map_tokens = map_tokens.to(self.device)
        edge_index = edge_index.to(self.device)
        track_encoded = self.track_encoder(track_tokens)
        #Honestly, I have no idea whether I should normalize the map and track tokens or not
        graph_data = Data(x=map_tokens, edge_index=edge_index)
        map_encoded = self.map_encoder_gnn(graph_data.x, graph_data.edge_index)
        map_encoded = self.map_encoder_post(map_encoded)
        track_quantized = self.codebook(torch.argmax(track_encoded, dim=-1))
        map_quantized = self.codebook(torch.argmax(map_encoded, dim=-1))
        # Thinking of adding another layer for map_quamtized not sure if its a good idea to increase the parameters
        track_decoded = self.track_decoder(track_quantized)
        map_decoded = self.map_decoder(map_quantized)
        return track_decoded, map_decoded, track_quantized, map_quantized, track_encoded, map_encoded
    
    def calculate_loss(self, track_tokens, map_tokens, track_decoded, map_decoded, track_quantized, map_quantized, track_encoded, map_encoded):
        # Need to play around this yet I just added the loss function from original paper
        track_decoded = track_decoded.view(-1, track_decoded.shape[-1])
        map_decoded = map_decoded.view(-1, map_decoded.shape[-1])
        track_loss = self.reconstruction_loss(track_decoded, track_tokens.view(-1, track_tokens.shape[-1]))
        map_loss = self.reconstruction_loss(map_decoded, map_tokens.view(-1, map_tokens.shape[-1]))
        commitment_loss = self.commitment_loss_weight * (torch.mean((track_encoded.detach()-track_quantized)**2)+torch.mean((map_encoded.detach()- map_quantized)** 2))
        codebook_loss = torch.mean((track_encoded - track_quantized.detach()) ** 2) + \
                         torch.mean((map_encoded - map_quantized.detach()) ** 2)
        total_loss = track_loss + map_loss + commitment_loss + codebook_loss
        return total_loss, track_loss, map_loss, commitment_loss, codebook_loss
    
    def train_model(self, scenarios):
        self.train()
        dataloader = DataLoader(scenarios, batch_size=1, shuffle=True, collate_fn=custom_collate_fn)
        for epoch in range(self.epochs):
            total_loss = 0
            for batch in dataloader:
                if batch['tracks'].nelement() > 0 and batch['map_features'].nelement() > 0:
                    track_tokens = batch['tracks'].to(self.device)
                    map_tokens = batch['map_features'].to(self.device)
                    edge_index = batch['edge_index'].to(self.device)
                    self.optimizer.zero_grad()
                    track_decoded, map_decoded, track_quantized, map_quantized, track_encoded, map_encoded = self.forward(track_tokens, map_tokens, edge_index)
                    loss, track_loss, map_loss, commitment_loss, codebook_loss = self.calculate_loss(track_tokens, map_tokens, track_decoded, map_decoded, track_quantized, map_quantized, track_encoded, map_encoded)
                    loss.backward()
                    nn.utils.clip_grad_norm_(self.parameters(), max_norm=1.0)
                    self.optimizer.step()
                    total_loss += loss.item()
                
            print(f"Epoch [{epoch+1}/{self.epochs}] | Total Loss: {total_loss / len(dataloader):.4f} | "
                  f"Track Loss: {track_loss.item():.4f} | Map Loss: {map_loss.item():.4f} | "
                  f"Commitment Loss: {commitment_loss.item():.4f} | Codebook Loss: {codebook_loss.item():.4f}")
        torch.save(self.state_dict(), 'avqvae_final.pth')

# %%
vqvae = AVQVAE(device='cuda')
vqvae.train_model([tokens])
# Just loaded one scenario need to check the loss and other stuffs currently the loss is not decreasing
# Out:
# /home/light/Documents/Thesis/thesis/lib/python3.10/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch [1/2000] | Total Loss: 1871.2417 | Track Loss: 467.1244 | Map Loss: 1400.9512 | Commitment Loss: 0.2878 | Codebook Loss: 2.8783
# Epoch [2/2000] | Total Loss: 1869.4338 | Track Loss: 466.3592 | Map Loss: 1399.5183 | Commitment Loss: 0.3233 | Codebook Loss: 3.2331
# Epoch [3/2000] | Total Loss: 1867.4413 | Track Loss: 465.6418 | Map Loss: 1398.5233 | Commitment Loss: 0.2978 | Codebook Loss: 2.9783
# Epoch [4/2000] | Total Loss: 1867.3229 | Track Loss: 465.3111 | Map Loss: 1398.8956 | Commitment Loss: 0.2833 | Codebook Loss: 2.8328
# Epoch [5/2000] | Total Loss: 1865.1094 | Track Loss: 464.9706 | Map Loss: 1397.2604 | Commitment Loss: 0.2617 | Codebook Loss: 2.6167
# Epoch [6/2000] | Total Loss: 1863.3250 | Track Loss: 464.5686 | Map Loss: 1396.0995 | Commitment Loss: 0.2415 | Codebook Loss: 2.4152
# Epoch [7/2000] | Total Loss: 1861.7893 | Track Loss: 464.2170 | Map Loss: 1395.0173 | Commitment Loss: 0.2323 | Codebook Loss: 2.3226
# Epoch [8/2000] | Total Loss: 1860.0726 | Track Loss: 463.8891 | Map Loss: 1393.6577 | Commitment Loss: 0.2296 | Codebook Loss: 2.2962
# Epoch [9/2000] | Total Loss: 1858.8046 | Track Loss: 463.5437 | Map Loss: 1392.8877 | Commitment Loss: 0.2157 | Codebook Loss: 2.1574
# Epoch [10/2000] | Total Loss: 1857.2838 | Track Loss: 463.2319 | Map Loss: 1391.7239 | Commitment Loss: 0.2116 | Codebook Loss: 2.1163
# Epoch [11/2000] | Total Loss: 1855.3483 | Track Loss: 462.8225 | Map Loss: 1390.3198 | Commitment Loss: 0.2005 | Codebook Loss: 2.0053
# Epoch [12/2000] | Total Loss: 1853.5636 | Track Loss: 462.4514 | Map Loss: 1388.7714 | Commitment Loss: 0.2128 | Codebook Loss: 2.1281
# Epoch [13/2000] | Total Loss: 1852.4154 | Track Loss: 462.0909 | Map Loss: 1387.7528 | Commitment Loss: 0.2338 | Codebook Loss: 2.3380
# Epoch [14/2000] | Total Loss: 1850.8850 | Track Loss: 461.6929 | Map Loss: 1386.6648 | Commitment Loss: 0.2298 | Codebook Loss: 2.2976
# Epoch [15/2000] | Total Loss: 1849.0023 | Track Loss: 461.3034 | Map Loss: 1385.2927 | Commitment Loss: 0.2187 | Codebook Loss: 2.1874
# Epoch [16/2000] | Total Loss: 1847.3135 | Track Loss: 460.8549 | Map Loss: 1384.0927 | Commitment Loss: 0.2151 | Codebook Loss: 2.1509
# Epoch [17/2000] | Total Loss: 1846.1439 | Track Loss: 460.4124 | Map Loss: 1383.4681 | Commitment Loss: 0.2058 | Codebook Loss: 2.0577
# Epoch [18/2000] | Total Loss: 1843.4500 | Track Loss: 459.9726 | Map Loss: 1381.3225 | Commitment Loss: 0.1959 | Codebook Loss: 1.9588
# Epoch [19/2000] | Total Loss: 1841.2675 | Track Loss: 459.5232 | Map Loss: 1379.6830 | Commitment Loss: 0.1874 | Codebook Loss: 1.8739
# Epoch [20/2000] | Total Loss: 1839.2814 | Track Loss: 459.0791 | Map Loss: 1378.2034 | Commitment Loss: 0.1817 | Codebook Loss: 1.8172
# Epoch [21/2000] | Total Loss: 1837.4259 | Track Loss: 458.6518 | Map Loss: 1376.7322 | Commitment Loss: 0.1856 | Codebook Loss: 1.8564
# Epoch [22/2000] | Total Loss: 1835.5133 | Track Loss: 458.1358 | Map Loss: 1375.2378 | Commitment Loss: 0.1945 | Codebook Loss: 1.9452
# Epoch [23/2000] | Total Loss: 1833.6190 | Track Loss: 457.6220 | Map Loss: 1373.6707 | Commitment Loss: 0.2115 | Codebook Loss: 2.1149
# Epoch [24/2000] | Total Loss: 1831.4802 | Track Loss: 457.1009 | Map Loss: 1372.0709 | Commitment Loss: 0.2099 | Codebook Loss: 2.0986
# Epoch [25/2000] | Total Loss: 1829.6176 | Track Loss: 456.5581 | Map Loss: 1370.8219 | Commitment Loss: 0.2034 | Codebook Loss: 2.0342
# Epoch [26/2000] | Total Loss: 1828.9652 | Track Loss: 456.0169 | Map Loss: 1370.7804 | Commitment Loss: 0.1971 | Codebook Loss: 1.9708
# Epoch [27/2000] | Total Loss: 1826.5858 | Track Loss: 455.4638 | Map Loss: 1369.0366 | Commitment Loss: 0.1896 | Codebook Loss: 1.8957
# Epoch [28/2000] | Total Loss: 1822.6317 | Track Loss: 454.8961 | Map Loss: 1365.7302 | Commitment Loss: 0.1823 | Codebook Loss: 1.8231
# Epoch [29/2000] | Total Loss: 1820.2767 | Track Loss: 454.3147 | Map Loss: 1364.0236 | Commitment Loss: 0.1762 | Codebook Loss: 1.7622
# Epoch [30/2000] | Total Loss: 1818.0338 | Track Loss: 453.7387 | Map Loss: 1362.4144 | Commitment Loss: 0.1710 | Codebook Loss: 1.7097
# Epoch [31/2000] | Total Loss: 1815.7689 | Track Loss: 453.2056 | Map Loss: 1360.5549 | Commitment Loss: 0.1826 | Codebook Loss: 1.8258
# Epoch [32/2000] | Total Loss: 1814.9767 | Track Loss: 452.5159 | Map Loss: 1360.4015 | Commitment Loss: 0.1872 | Codebook Loss: 1.8720
# Epoch [33/2000] | Total Loss: 1816.6318 | Track Loss: 451.8814 | Map Loss: 1362.6882 | Commitment Loss: 0.1875 | Codebook Loss: 1.8747
# Epoch [34/2000] | Total Loss: 1813.7052 | Track Loss: 451.2111 | Map Loss: 1360.4845 | Commitment Loss: 0.1827 | Codebook Loss: 1.8269
# Epoch [35/2000] | Total Loss: 1812.3274 | Track Loss: 450.5324 | Map Loss: 1359.8182 | Commitment Loss: 0.1797 | Codebook Loss: 1.7971
# Epoch [36/2000] | Total Loss: 1809.1896 | Track Loss: 449.8450 | Map Loss: 1357.4178 | Commitment Loss: 0.1751 | Codebook Loss: 1.7515
# Epoch [37/2000] | Total Loss: 1807.0785 | Track Loss: 449.1365 | Map Loss: 1356.0271 | Commitment Loss: 0.1741 | Codebook Loss: 1.7408
# Epoch [38/2000] | Total Loss: 1804.4642 | Track Loss: 448.4048 | Map Loss: 1354.1467 | Commitment Loss: 0.1739 | Codebook Loss: 1.7388
# Epoch [39/2000] | Total Loss: 1801.2155 | Track Loss: 447.6562 | Map Loss: 1351.6799 | Commitment Loss: 0.1708 | Codebook Loss: 1.7085
# Epoch [40/2000] | Total Loss: 1799.5380 | Track Loss: 446.8955 | Map Loss: 1350.8009 | Commitment Loss: 0.1674 | Codebook Loss: 1.6742
# Epoch [41/2000] | Total Loss: 1796.4856 | Track Loss: 446.1526 | Map Loss: 1348.4854 | Commitment Loss: 0.1680 | Codebook Loss: 1.6797
# Epoch [42/2000] | Total Loss: 1795.2605 | Track Loss: 445.3583 | Map Loss: 1347.8807 | Commitment Loss: 0.1838 | Codebook Loss: 1.8377
# Epoch [43/2000] | Total Loss: 1792.0804 | Track Loss: 444.5355 | Map Loss: 1345.4725 | Commitment Loss: 0.1884 | Codebook Loss: 1.8840
# Epoch [44/2000] | Total Loss: 1788.9149 | Track Loss: 443.6913 | Map Loss: 1343.1637 | Commitment Loss: 0.1873 | Codebook Loss: 1.8727
# Epoch [45/2000] | Total Loss: 1787.1901 | Track Loss: 442.8401 | Map Loss: 1342.3213 | Commitment Loss: 0.1844 | Codebook Loss: 1.8443
# Epoch [46/2000] | Total Loss: 1783.2277 | Track Loss: 441.9793 | Map Loss: 1339.2743 | Commitment Loss: 0.1795 | Codebook Loss: 1.7946
# Epoch [47/2000] | Total Loss: 1779.0519 | Track Loss: 441.1029 | Map Loss: 1336.0262 | Commitment Loss: 0.1748 | Codebook Loss: 1.7479
# Epoch [48/2000] | Total Loss: 1776.3579 | Track Loss: 440.2139 | Map Loss: 1334.2552 | Commitment Loss: 0.1717 | Codebook Loss: 1.7170
# Epoch [49/2000] | Total Loss: 1772.3191 | Track Loss: 439.3235 | Map Loss: 1331.0543 | Commitment Loss: 0.1765 | Codebook Loss: 1.7648
# Epoch [50/2000] | Total Loss: 1768.1555 | Track Loss: 438.4463 | Map Loss: 1327.6289 | Commitment Loss: 0.1891 | Codebook Loss: 1.8912
# Epoch [51/2000] | Total Loss: 1763.1169 | Track Loss: 437.4774 | Map Loss: 1323.6014 | Commitment Loss: 0.1853 | Codebook Loss: 1.8528
# Epoch [52/2000] | Total Loss: 1755.7854 | Track Loss: 436.5191 | Map Loss: 1317.3009 | Commitment Loss: 0.1787 | Codebook Loss: 1.7866
# Epoch [53/2000] | Total Loss: 1749.3628 | Track Loss: 435.5671 | Map Loss: 1311.8622 | Commitment Loss: 0.1758 | Codebook Loss: 1.7578
# Epoch [54/2000] | Total Loss: 1745.8501 | Track Loss: 434.6111 | Map Loss: 1309.3552 | Commitment Loss: 0.1713 | Codebook Loss: 1.7126
# Epoch [55/2000] | Total Loss: 1744.9640 | Track Loss: 433.6379 | Map Loss: 1309.4739 | Commitment Loss: 0.1684 | Codebook Loss: 1.6838
# Epoch [56/2000] | Total Loss: 1741.2156 | Track Loss: 432.6597 | Map Loss: 1306.7227 | Commitment Loss: 0.1667 | Codebook Loss: 1.6666
# Epoch [57/2000] | Total Loss: 1735.6785 | Track Loss: 431.6727 | Map Loss: 1302.2203 | Commitment Loss: 0.1623 | Codebook Loss: 1.6230
# Epoch [58/2000] | Total Loss: 1730.0840 | Track Loss: 430.6990 | Map Loss: 1297.6145 | Commitment Loss: 0.1610 | Codebook Loss: 1.6096
# Epoch [59/2000] | Total Loss: 1727.1619 | Track Loss: 429.7334 | Map Loss: 1295.5127 | Commitment Loss: 0.1742 | Codebook Loss: 1.7416
# Epoch [60/2000] | Total Loss: 1722.1567 | Track Loss: 428.6940 | Map Loss: 1291.4263 | Commitment Loss: 0.1851 | Codebook Loss: 1.8514
# Epoch [61/2000] | Total Loss: 1718.6354 | Track Loss: 427.6724 | Map Loss: 1288.9086 | Commitment Loss: 0.1868 | Codebook Loss: 1.8676
# Epoch [62/2000] | Total Loss: 1710.8674 | Track Loss: 426.6388 | Map Loss: 1282.2271 | Commitment Loss: 0.1820 | Codebook Loss: 1.8195
# Epoch [63/2000] | Total Loss: 1705.9415 | Track Loss: 425.6146 | Map Loss: 1278.3478 | Commitment Loss: 0.1799 | Codebook Loss: 1.7992
# Epoch [64/2000] | Total Loss: 1701.7020 | Track Loss: 424.6333 | Map Loss: 1275.0903 | Commitment Loss: 0.1799 | Codebook Loss: 1.7986
# Epoch [65/2000] | Total Loss: 1697.5001 | Track Loss: 423.6336 | Map Loss: 1271.8696 | Commitment Loss: 0.1815 | Codebook Loss: 1.8155
# Epoch [66/2000] | Total Loss: 1693.3394 | Track Loss: 422.5047 | Map Loss: 1268.9810 | Commitment Loss: 0.1685 | Codebook Loss: 1.6852
# Epoch [67/2000] | Total Loss: 1688.3893 | Track Loss: 421.3989 | Map Loss: 1265.1876 | Commitment Loss: 0.1639 | Codebook Loss: 1.6388
# Epoch [68/2000] | Total Loss: 1683.8456 | Track Loss: 420.3324 | Map Loss: 1261.7345 | Commitment Loss: 0.1617 | Codebook Loss: 1.6169
# Epoch [69/2000] | Total Loss: 1679.3470 | Track Loss: 419.2524 | Map Loss: 1258.3495 | Commitment Loss: 0.1587 | Codebook Loss: 1.5866
# Epoch [70/2000] | Total Loss: 1674.9612 | Track Loss: 418.1610 | Map Loss: 1255.0511 | Commitment Loss: 0.1590 | Codebook Loss: 1.5900
# Epoch [71/2000] | Total Loss: 1670.3481 | Track Loss: 417.0649 | Map Loss: 1251.5145 | Commitment Loss: 0.1608 | Codebook Loss: 1.6081
# Epoch [72/2000] | Total Loss: 1665.9210 | Track Loss: 415.9567 | Map Loss: 1248.1527 | Commitment Loss: 0.1647 | Codebook Loss: 1.6469
# Epoch [73/2000] | Total Loss: 1661.4705 | Track Loss: 414.8367 | Map Loss: 1244.7722 | Commitment Loss: 0.1692 | Codebook Loss: 1.6923
# Epoch [74/2000] | Total Loss: 1656.5343 | Track Loss: 413.7119 | Map Loss: 1240.9691 | Commitment Loss: 0.1685 | Codebook Loss: 1.6849
# Epoch [75/2000] | Total Loss: 1651.8440 | Track Loss: 412.5746 | Map Loss: 1237.4266 | Commitment Loss: 0.1675 | Codebook Loss: 1.6753
# Epoch [76/2000] | Total Loss: 1646.9841 | Track Loss: 411.4302 | Map Loss: 1233.7528 | Commitment Loss: 0.1637 | Codebook Loss: 1.6374
# Epoch [77/2000] | Total Loss: 1642.1414 | Track Loss: 410.2791 | Map Loss: 1230.0908 | Commitment Loss: 0.1610 | Codebook Loss: 1.6105
# Epoch [78/2000] | Total Loss: 1637.2017 | Track Loss: 409.1150 | Map Loss: 1226.3718 | Commitment Loss: 0.1559 | Codebook Loss: 1.5590
# Epoch [79/2000] | Total Loss: 1632.3060 | Track Loss: 407.9423 | Map Loss: 1222.6892 | Commitment Loss: 0.1522 | Codebook Loss: 1.5222
# Epoch [80/2000] | Total Loss: 1627.2864 | Track Loss: 406.7615 | Map Loss: 1218.8867 | Commitment Loss: 0.1489 | Codebook Loss: 1.4892
# Epoch [81/2000] | Total Loss: 1622.2394 | Track Loss: 405.5749 | Map Loss: 1215.0891 | Commitment Loss: 0.1432 | Codebook Loss: 1.4322
# Epoch [82/2000] | Total Loss: 1617.1853 | Track Loss: 404.3798 | Map Loss: 1211.2517 | Commitment Loss: 0.1412 | Codebook Loss: 1.4124
# Epoch [83/2000] | Total Loss: 1612.1073 | Track Loss: 403.1830 | Map Loss: 1207.3793 | Commitment Loss: 0.1405 | Codebook Loss: 1.4046
# Epoch [84/2000] | Total Loss: 1607.1213 | Track Loss: 401.9789 | Map Loss: 1203.4719 | Commitment Loss: 0.1519 | Codebook Loss: 1.5187
# Epoch [85/2000] | Total Loss: 1602.0461 | Track Loss: 400.7318 | Map Loss: 1199.5300 | Commitment Loss: 0.1622 | Codebook Loss: 1.6221
# Epoch [86/2000] | Total Loss: 1596.8474 | Track Loss: 399.4772 | Map Loss: 1195.5605 | Commitment Loss: 0.1645 | Codebook Loss: 1.6452
# Epoch [87/2000] | Total Loss: 1591.6434 | Track Loss: 398.2289 | Map Loss: 1191.5543 | Commitment Loss: 0.1691 | Codebook Loss: 1.6912
# Epoch [88/2000] | Total Loss: 1586.3491 | Track Loss: 396.9677 | Map Loss: 1187.5161 | Commitment Loss: 0.1696 | Codebook Loss: 1.6957
# Epoch [89/2000] | Total Loss: 1580.9775 | Track Loss: 395.6956 | Map Loss: 1183.4435 | Commitment Loss: 0.1671 | Codebook Loss: 1.6714
# Epoch [90/2000] | Total Loss: 1575.5664 | Track Loss: 394.4209 | Map Loss: 1179.3381 | Commitment Loss: 0.1643 | Codebook Loss: 1.6431
# Epoch [91/2000] | Total Loss: 1570.1193 | Track Loss: 393.1326 | Map Loss: 1175.1984 | Commitment Loss: 0.1626 | Codebook Loss: 1.6256
# Epoch [92/2000] | Total Loss: 1564.6215 | Track Loss: 391.8381 | Map Loss: 1171.0269 | Commitment Loss: 0.1597 | Codebook Loss: 1.5968
# Epoch [93/2000] | Total Loss: 1559.0823 | Track Loss: 390.5167 | Map Loss: 1166.8239 | Commitment Loss: 0.1583 | Codebook Loss: 1.5834
# Epoch [94/2000] | Total Loss: 1553.4877 | Track Loss: 389.1811 | Map Loss: 1162.5835 | Commitment Loss: 0.1566 | Codebook Loss: 1.5664
# Epoch [95/2000] | Total Loss: 1547.8678 | Track Loss: 387.8450 | Map Loss: 1158.3148 | Commitment Loss: 0.1553 | Codebook Loss: 1.5527
# Epoch [96/2000] | Total Loss: 1542.2140 | Track Loss: 386.5065 | Map Loss: 1154.0106 | Commitment Loss: 0.1543 | Codebook Loss: 1.5426
# Epoch [97/2000] | Total Loss: 1536.5116 | Track Loss: 385.1550 | Map Loss: 1149.6700 | Commitment Loss: 0.1533 | Codebook Loss: 1.5332
# Epoch [98/2000] | Total Loss: 1530.7496 | Track Loss: 383.7767 | Map Loss: 1145.3009 | Commitment Loss: 0.1520 | Codebook Loss: 1.5200
# Epoch [99/2000] | Total Loss: 1525.1108 | Track Loss: 382.3984 | Map Loss: 1141.0629 | Commitment Loss: 0.1500 | Codebook Loss: 1.4996
# Epoch [100/2000] | Total Loss: 1519.1038 | Track Loss: 381.0138 | Map Loss: 1136.4635 | Commitment Loss: 0.1479 | Codebook Loss: 1.4786
# Epoch [101/2000] | Total Loss: 1513.1929 | Track Loss: 379.6165 | Map Loss: 1131.9989 | Commitment Loss: 0.1434 | Codebook Loss: 1.4339
# Epoch [102/2000] | Total Loss: 1507.2434 | Track Loss: 378.2099 | Map Loss: 1127.4960 | Commitment Loss: 0.1398 | Codebook Loss: 1.3979
# Epoch [103/2000] | Total Loss: 1501.2609 | Track Loss: 376.7946 | Map Loss: 1122.9658 | Commitment Loss: 0.1364 | Codebook Loss: 1.3640
# Epoch [104/2000] | Total Loss: 1495.6023 | Track Loss: 375.3671 | Map Loss: 1118.7782 | Commitment Loss: 0.1325 | Codebook Loss: 1.3246
# Epoch [105/2000] | Total Loss: 1489.2129 | Track Loss: 373.9307 | Map Loss: 1113.8510 | Commitment Loss: 0.1301 | Codebook Loss: 1.3011
# Epoch [106/2000] | Total Loss: 1483.0721 | Track Loss: 372.4834 | Map Loss: 1109.1923 | Commitment Loss: 0.1270 | Codebook Loss: 1.2696
# Epoch [107/2000] | Total Loss: 1476.9340 | Track Loss: 371.0268 | Map Loss: 1104.5272 | Commitment Loss: 0.1254 | Codebook Loss: 1.2544
# Epoch [108/2000] | Total Loss: 1470.7463 | Track Loss: 369.5594 | Map Loss: 1099.8273 | Commitment Loss: 0.1236 | Codebook Loss: 1.2360
# Epoch [109/2000] | Total Loss: 1464.5294 | Track Loss: 368.0824 | Map Loss: 1095.1030 | Commitment Loss: 0.1222 | Codebook Loss: 1.2218
# Epoch [110/2000] | Total Loss: 1458.5430 | Track Loss: 366.5999 | Map Loss: 1090.5684 | Commitment Loss: 0.1250 | Codebook Loss: 1.2498
# Epoch [111/2000] | Total Loss: 1452.1278 | Track Loss: 365.1146 | Map Loss: 1085.5593 | Commitment Loss: 0.1322 | Codebook Loss: 1.3218
# Epoch [112/2000] | Total Loss: 1446.0320 | Track Loss: 363.6119 | Map Loss: 1080.7437 | Commitment Loss: 0.1524 | Codebook Loss: 1.5240
# Epoch [113/2000] | Total Loss: 1439.8340 | Track Loss: 362.0827 | Map Loss: 1075.8906 | Commitment Loss: 0.1691 | Codebook Loss: 1.6914
# Epoch [114/2000] | Total Loss: 1433.4518 | Track Loss: 360.5576 | Map Loss: 1071.0099 | Commitment Loss: 0.1713 | Codebook Loss: 1.7131
# Epoch [115/2000] | Total Loss: 1427.0249 | Track Loss: 359.0323 | Map Loss: 1066.0981 | Commitment Loss: 0.1722 | Codebook Loss: 1.7223
# Epoch [116/2000] | Total Loss: 1420.5288 | Track Loss: 357.5247 | Map Loss: 1061.1479 | Commitment Loss: 0.1688 | Codebook Loss: 1.6875
# Epoch [117/2000] | Total Loss: 1414.0062 | Track Loss: 356.0343 | Map Loss: 1056.1752 | Commitment Loss: 0.1633 | Codebook Loss: 1.6334
# Epoch [118/2000] | Total Loss: 1407.3379 | Track Loss: 354.4225 | Map Loss: 1051.1643 | Commitment Loss: 0.1592 | Codebook Loss: 1.5918
# Epoch [119/2000] | Total Loss: 1400.7875 | Track Loss: 352.8834 | Map Loss: 1046.1255 | Commitment Loss: 0.1617 | Codebook Loss: 1.6170
# Epoch [120/2000] | Total Loss: 1394.0792 | Track Loss: 351.2450 | Map Loss: 1041.0538 | Commitment Loss: 0.1619 | Codebook Loss: 1.6185
# Epoch [121/2000] | Total Loss: 1387.4021 | Track Loss: 349.6566 | Map Loss: 1035.9536 | Commitment Loss: 0.1629 | Codebook Loss: 1.6290
# Epoch [122/2000] | Total Loss: 1380.6404 | Track Loss: 348.0369 | Map Loss: 1030.8229 | Commitment Loss: 0.1619 | Codebook Loss: 1.6187
# Epoch [123/2000] | Total Loss: 1373.7816 | Track Loss: 346.4011 | Map Loss: 1025.6658 | Commitment Loss: 0.1559 | Codebook Loss: 1.5588
# Epoch [124/2000] | Total Loss: 1366.9297 | Track Loss: 344.7832 | Map Loss: 1020.4744 | Commitment Loss: 0.1520 | Codebook Loss: 1.5202
# Epoch [125/2000] | Total Loss: 1360.0385 | Track Loss: 343.1514 | Map Loss: 1015.2529 | Commitment Loss: 0.1486 | Codebook Loss: 1.4856
# Epoch [126/2000] | Total Loss: 1353.1274 | Track Loss: 341.5061 | Map Loss: 1010.0052 | Commitment Loss: 0.1469 | Codebook Loss: 1.4692
# Epoch [127/2000] | Total Loss: 1346.1925 | Track Loss: 339.8644 | Map Loss: 1004.7209 | Commitment Loss: 0.1461 | Codebook Loss: 1.4611
# Epoch [128/2000] | Total Loss: 1339.2280 | Track Loss: 338.2072 | Map Loss: 999.4073 | Commitment Loss: 0.1467 | Codebook Loss: 1.4668
# Epoch [129/2000] | Total Loss: 1332.2402 | Track Loss: 336.5087 | Map Loss: 994.0650 | Commitment Loss: 0.1515 | Codebook Loss: 1.5150
# Epoch [130/2000] | Total Loss: 1325.1764 | Track Loss: 334.8138 | Map Loss: 988.6907 | Commitment Loss: 0.1520 | Codebook Loss: 1.5200
# Epoch [131/2000] | Total Loss: 1318.0724 | Track Loss: 333.1368 | Map Loss: 983.2869 | Commitment Loss: 0.1499 | Codebook Loss: 1.4988
# Epoch [132/2000] | Total Loss: 1310.9390 | Track Loss: 331.4619 | Map Loss: 977.8519 | Commitment Loss: 0.1477 | Codebook Loss: 1.4775
# Epoch [133/2000] | Total Loss: 1303.7365 | Track Loss: 329.7416 | Map Loss: 972.3895 | Commitment Loss: 0.1459 | Codebook Loss: 1.4594
# Epoch [134/2000] | Total Loss: 1296.4572 | Track Loss: 327.9867 | Map Loss: 966.8962 | Commitment Loss: 0.1431 | Codebook Loss: 1.4311
# Epoch [135/2000] | Total Loss: 1289.1714 | Track Loss: 326.2603 | Map Loss: 961.3726 | Commitment Loss: 0.1399 | Codebook Loss: 1.3985
# Epoch [136/2000] | Total Loss: 1281.8323 | Track Loss: 324.5107 | Map Loss: 955.8193 | Commitment Loss: 0.1366 | Codebook Loss: 1.3656
# Epoch [137/2000] | Total Loss: 1274.4617 | Track Loss: 322.7586 | Map Loss: 950.2350 | Commitment Loss: 0.1335 | Codebook Loss: 1.3346
# Epoch [138/2000] | Total Loss: 1267.0552 | Track Loss: 321.0063 | Map Loss: 944.6219 | Commitment Loss: 0.1297 | Codebook Loss: 1.2971
# Epoch [139/2000] | Total Loss: 1259.6074 | Track Loss: 319.2313 | Map Loss: 938.9762 | Commitment Loss: 0.1273 | Codebook Loss: 1.2726
# Epoch [140/2000] | Total Loss: 1252.3245 | Track Loss: 317.5518 | Map Loss: 933.3026 | Commitment Loss: 0.1336 | Codebook Loss: 1.3364
# Epoch [141/2000] | Total Loss: 1245.0686 | Track Loss: 315.7726 | Map Loss: 927.5971 | Commitment Loss: 0.1544 | Codebook Loss: 1.5444
# Epoch [142/2000] | Total Loss: 1237.4707 | Track Loss: 313.9041 | Map Loss: 921.8674 | Commitment Loss: 0.1545 | Codebook Loss: 1.5448
# Epoch [143/2000] | Total Loss: 1230.2545 | Track Loss: 312.1243 | Map Loss: 916.4435 | Commitment Loss: 0.1533 | Codebook Loss: 1.5334
# Epoch [144/2000] | Total Loss: 1222.2776 | Track Loss: 310.2983 | Map Loss: 910.3058 | Commitment Loss: 0.1521 | Codebook Loss: 1.5215
# Epoch [145/2000] | Total Loss: 1214.5695 | Track Loss: 308.4414 | Map Loss: 904.4804 | Commitment Loss: 0.1498 | Codebook Loss: 1.4979
# Epoch [146/2000] | Total Loss: 1206.8457 | Track Loss: 306.6019 | Map Loss: 898.6294 | Commitment Loss: 0.1468 | Codebook Loss: 1.4678
# Epoch [147/2000] | Total Loss: 1199.0986 | Track Loss: 304.7606 | Map Loss: 892.7463 | Commitment Loss: 0.1447 | Codebook Loss: 1.4471
# Epoch [148/2000] | Total Loss: 1191.3026 | Track Loss: 302.8987 | Map Loss: 886.8406 | Commitment Loss: 0.1421 | Codebook Loss: 1.4213
# Epoch [149/2000] | Total Loss: 1183.4550 | Track Loss: 301.0261 | Map Loss: 880.8950 | Commitment Loss: 0.1395 | Codebook Loss: 1.3945
# Epoch [150/2000] | Total Loss: 1175.5759 | Track Loss: 299.1497 | Map Loss: 874.9219 | Commitment Loss: 0.1368 | Codebook Loss: 1.3677
# Epoch [151/2000] | Total Loss: 1167.6720 | Track Loss: 297.2664 | Map Loss: 868.9208 | Commitment Loss: 0.1350 | Codebook Loss: 1.3497
# Epoch [152/2000] | Total Loss: 1159.7181 | Track Loss: 295.3686 | Map Loss: 862.8926 | Commitment Loss: 0.1325 | Codebook Loss: 1.3246
# Epoch [153/2000] | Total Loss: 1151.7395 | Track Loss: 293.4754 | Map Loss: 856.8298 | Commitment Loss: 0.1304 | Codebook Loss: 1.3040
# Epoch [154/2000] | Total Loss: 1144.4369 | Track Loss: 291.8981 | Map Loss: 850.7405 | Commitment Loss: 0.1635 | Codebook Loss: 1.6349
# Epoch [155/2000] | Total Loss: 1136.1345 | Track Loss: 289.7202 | Map Loss: 844.6210 | Commitment Loss: 0.1630 | Codebook Loss: 1.6302
# Epoch [156/2000] | Total Loss: 1128.1398 | Track Loss: 287.8759 | Map Loss: 838.4796 | Commitment Loss: 0.1622 | Codebook Loss: 1.6221
# Epoch [157/2000] | Total Loss: 1119.9640 | Track Loss: 285.8746 | Map Loss: 832.3206 | Commitment Loss: 0.1608 | Codebook Loss: 1.6081
# Epoch [158/2000] | Total Loss: 1112.1580 | Track Loss: 283.8545 | Map Loss: 826.5407 | Commitment Loss: 0.1602 | Codebook Loss: 1.6024
# Epoch [159/2000] | Total Loss: 1103.6027 | Track Loss: 281.9419 | Map Loss: 819.9183 | Commitment Loss: 0.1584 | Codebook Loss: 1.5840
# Epoch [160/2000] | Total Loss: 1095.3864 | Track Loss: 279.9894 | Map Loss: 813.6725 | Commitment Loss: 0.1568 | Codebook Loss: 1.5677
# Epoch [161/2000] | Total Loss: 1087.0814 | Track Loss: 277.9786 | Map Loss: 807.4045 | Commitment Loss: 0.1544 | Codebook Loss: 1.5439
# Epoch [162/2000] | Total Loss: 1078.7994 | Track Loss: 276.0130 | Map Loss: 801.1055 | Commitment Loss: 0.1528 | Codebook Loss: 1.5282
# Epoch [163/2000] | Total Loss: 1070.4567 | Track Loss: 274.0228 | Map Loss: 794.7775 | Commitment Loss: 0.1506 | Codebook Loss: 1.5057
# Epoch [164/2000] | Total Loss: 1062.0590 | Track Loss: 272.0023 | Map Loss: 788.4210 | Commitment Loss: 0.1487 | Codebook Loss: 1.4870
# Epoch [165/2000] | Total Loss: 1053.6575 | Track Loss: 270.0009 | Map Loss: 782.0362 | Commitment Loss: 0.1473 | Codebook Loss: 1.4730
# Epoch [166/2000] | Total Loss: 1045.6246 | Track Loss: 267.9788 | Map Loss: 776.0605 | Commitment Loss: 0.1441 | Codebook Loss: 1.4412
# Epoch [167/2000] | Total Loss: 1036.7009 | Track Loss: 265.9476 | Map Loss: 769.1748 | Commitment Loss: 0.1435 | Codebook Loss: 1.4350
# Epoch [168/2000] | Total Loss: 1028.1660 | Track Loss: 263.9168 | Map Loss: 762.7012 | Commitment Loss: 0.1407 | Codebook Loss: 1.4073
# Epoch [169/2000] | Total Loss: 1019.5884 | Track Loss: 261.8615 | Map Loss: 756.1974 | Commitment Loss: 0.1390 | Codebook Loss: 1.3905
# Epoch [170/2000] | Total Loss: 1010.9834 | Track Loss: 259.8074 | Map Loss: 749.6621 | Commitment Loss: 0.1376 | Codebook Loss: 1.3763
# Epoch [171/2000] | Total Loss: 1002.3511 | Track Loss: 257.7455 | Map Loss: 743.1002 | Commitment Loss: 0.1369 | Codebook Loss: 1.3686
# Epoch [172/2000] | Total Loss: 993.8116 | Track Loss: 255.6932 | Map Loss: 736.5049 | Commitment Loss: 0.1467 | Codebook Loss: 1.4668
# Epoch [173/2000] | Total Loss: 985.1277 | Track Loss: 253.5921 | Map Loss: 729.8828 | Commitment Loss: 0.1503 | Codebook Loss: 1.5025
# Epoch [174/2000] | Total Loss: 976.3470 | Track Loss: 251.4882 | Map Loss: 723.2300 | Commitment Loss: 0.1481 | Codebook Loss: 1.4807
# Epoch [175/2000] | Total Loss: 967.5285 | Track Loss: 249.3901 | Map Loss: 716.5478 | Commitment Loss: 0.1446 | Codebook Loss: 1.4460
# Epoch [176/2000] | Total Loss: 958.6951 | Track Loss: 247.2864 | Map Loss: 709.8355 | Commitment Loss: 0.1430 | Codebook Loss: 1.4303
# Epoch [177/2000] | Total Loss: 949.7997 | Track Loss: 245.1657 | Map Loss: 703.0947 | Commitment Loss: 0.1399 | Codebook Loss: 1.3994
# Epoch [178/2000] | Total Loss: 940.8652 | Track Loss: 243.0356 | Map Loss: 696.3249 | Commitment Loss: 0.1368 | Codebook Loss: 1.3679
# Epoch [179/2000] | Total Loss: 931.9324 | Track Loss: 240.9101 | Map Loss: 689.5254 | Commitment Loss: 0.1361 | Codebook Loss: 1.3609
# Epoch [180/2000] | Total Loss: 923.0178 | Track Loss: 238.7789 | Map Loss: 682.6965 | Commitment Loss: 0.1402 | Codebook Loss: 1.4022
# Epoch [181/2000] | Total Loss: 913.9910 | Track Loss: 236.6220 | Map Loss: 675.8391 | Commitment Loss: 0.1391 | Codebook Loss: 1.3908
# Epoch [182/2000] | Total Loss: 904.9252 | Track Loss: 234.4561 | Map Loss: 668.9504 | Commitment Loss: 0.1381 | Codebook Loss: 1.3806
# Epoch [183/2000] | Total Loss: 895.8451 | Track Loss: 232.2505 | Map Loss: 662.0349 | Commitment Loss: 0.1418 | Codebook Loss: 1.4180
# Epoch [184/2000] | Total Loss: 886.9576 | Track Loss: 230.0677 | Map Loss: 655.3411 | Commitment Loss: 0.1408 | Codebook Loss: 1.4079
# Epoch [185/2000] | Total Loss: 877.5584 | Track Loss: 227.8839 | Map Loss: 648.1167 | Commitment Loss: 0.1416 | Codebook Loss: 1.4162
# Epoch [186/2000] | Total Loss: 868.3278 | Track Loss: 225.6717 | Map Loss: 641.1168 | Commitment Loss: 0.1399 | Codebook Loss: 1.3993
# Epoch [187/2000] | Total Loss: 859.0942 | Track Loss: 223.4495 | Map Loss: 634.0943 | Commitment Loss: 0.1409 | Codebook Loss: 1.4094
# Epoch [188/2000] | Total Loss: 849.7924 | Track Loss: 221.2238 | Map Loss: 627.0308 | Commitment Loss: 0.1398 | Codebook Loss: 1.3981
# Epoch [189/2000] | Total Loss: 840.4852 | Track Loss: 218.9911 | Map Loss: 619.9435 | Commitment Loss: 0.1410 | Codebook Loss: 1.4095
# Epoch [190/2000] | Total Loss: 831.6867 | Track Loss: 216.7543 | Map Loss: 613.3835 | Commitment Loss: 0.1408 | Codebook Loss: 1.4081
# Epoch [191/2000] | Total Loss: 821.7533 | Track Loss: 214.5099 | Map Loss: 605.6880 | Commitment Loss: 0.1414 | Codebook Loss: 1.4140
# Epoch [192/2000] | Total Loss: 812.3219 | Track Loss: 212.2528 | Map Loss: 598.5206 | Commitment Loss: 0.1408 | Codebook Loss: 1.4078
# Epoch [193/2000] | Total Loss: 802.8531 | Track Loss: 209.9861 | Map Loss: 591.3265 | Commitment Loss: 0.1400 | Codebook Loss: 1.4004
# Epoch [194/2000] | Total Loss: 793.3559 | Track Loss: 207.7066 | Map Loss: 584.1068 | Commitment Loss: 0.1402 | Codebook Loss: 1.4023
# Epoch [195/2000] | Total Loss: 783.8096 | Track Loss: 205.4175 | Map Loss: 576.8604 | Commitment Loss: 0.1392 | Codebook Loss: 1.3925
# Epoch [196/2000] | Total Loss: 775.3950 | Track Loss: 203.1219 | Map Loss: 570.7565 | Commitment Loss: 0.1379 | Codebook Loss: 1.3788
# Epoch [197/2000] | Total Loss: 764.6224 | Track Loss: 200.8180 | Map Loss: 562.2933 | Commitment Loss: 0.1374 | Codebook Loss: 1.3737
# Epoch [198/2000] | Total Loss: 754.9672 | Track Loss: 198.5051 | Map Loss: 554.9550 | Commitment Loss: 0.1370 | Codebook Loss: 1.3701
# Epoch [199/2000] | Total Loss: 745.8710 | Track Loss: 196.1863 | Map Loss: 548.1953 | Commitment Loss: 0.1354 | Codebook Loss: 1.3540
# Epoch [200/2000] | Total Loss: 735.5488 | Track Loss: 193.8610 | Map Loss: 540.2103 | Commitment Loss: 0.1343 | Codebook Loss: 1.3432
# Epoch [201/2000] | Total Loss: 725.8386 | Track Loss: 191.5245 | Map Loss: 532.8386 | Commitment Loss: 0.1341 | Codebook Loss: 1.3413
# Epoch [202/2000] | Total Loss: 716.3048 | Track Loss: 189.1820 | Map Loss: 525.6570 | Commitment Loss: 0.1333 | Codebook Loss: 1.3326
# Epoch [203/2000] | Total Loss: 707.2412 | Track Loss: 186.9159 | Map Loss: 518.8622 | Commitment Loss: 0.1330 | Codebook Loss: 1.3301
# Epoch [204/2000] | Total Loss: 699.2041 | Track Loss: 184.7549 | Map Loss: 513.0051 | Commitment Loss: 0.1313 | Codebook Loss: 1.3128
# Epoch [205/2000] | Total Loss: 692.1036 | Track Loss: 182.6659 | Map Loss: 507.9995 | Commitment Loss: 0.1307 | Codebook Loss: 1.3074
# Epoch [206/2000] | Total Loss: 685.4833 | Track Loss: 180.6610 | Map Loss: 503.3933 | Commitment Loss: 0.1299 | Codebook Loss: 1.2991
# Epoch [207/2000] | Total Loss: 680.0234 | Track Loss: 178.6805 | Map Loss: 499.9242 | Commitment Loss: 0.1290 | Codebook Loss: 1.2897
# Epoch [208/2000] | Total Loss: 674.8464 | Track Loss: 176.3480 | Map Loss: 497.0987 | Commitment Loss: 0.1272 | Codebook Loss: 1.2724
# Epoch [209/2000] | Total Loss: 671.3694 | Track Loss: 174.9634 | Map Loss: 495.0076 | Commitment Loss: 0.1271 | Codebook Loss: 1.2713
# Epoch [210/2000] | Total Loss: 665.8848 | Track Loss: 172.7014 | Map Loss: 491.7802 | Commitment Loss: 0.1276 | Codebook Loss: 1.2756
# Epoch [211/2000] | Total Loss: 661.9811 | Track Loss: 171.3646 | Map Loss: 489.2292 | Commitment Loss: 0.1261 | Codebook Loss: 1.2613
# Epoch [212/2000] | Total Loss: 657.4245 | Track Loss: 169.4322 | Map Loss: 486.6121 | Commitment Loss: 0.1255 | Codebook Loss: 1.2548
# Epoch [213/2000] | Total Loss: 653.3799 | Track Loss: 168.1243 | Map Loss: 483.8730 | Commitment Loss: 0.1257 | Codebook Loss: 1.2569
# Epoch [214/2000] | Total Loss: 649.2524 | Track Loss: 166.8660 | Map Loss: 480.9869 | Commitment Loss: 0.1272 | Codebook Loss: 1.2723
# Epoch [215/2000] | Total Loss: 644.5368 | Track Loss: 165.0981 | Map Loss: 477.9675 | Commitment Loss: 0.1337 | Codebook Loss: 1.3374
# Epoch [216/2000] | Total Loss: 640.6895 | Track Loss: 164.3406 | Map Loss: 474.7642 | Commitment Loss: 0.1441 | Codebook Loss: 1.4406
# Epoch [217/2000] | Total Loss: 636.4697 | Track Loss: 163.4563 | Map Loss: 471.4094 | Commitment Loss: 0.1458 | Codebook Loss: 1.4582
# Epoch [218/2000] | Total Loss: 632.0255 | Track Loss: 162.4796 | Map Loss: 467.9300 | Commitment Loss: 0.1469 | Codebook Loss: 1.4689
# Epoch [219/2000] | Total Loss: 627.5306 | Track Loss: 161.6102 | Map Loss: 464.3386 | Commitment Loss: 0.1438 | Codebook Loss: 1.4381
# Epoch [220/2000] | Total Loss: 622.9844 | Track Loss: 160.8448 | Map Loss: 460.6374 | Commitment Loss: 0.1366 | Codebook Loss: 1.3655
# Epoch [221/2000] | Total Loss: 618.1084 | Track Loss: 159.8623 | Map Loss: 456.8570 | Commitment Loss: 0.1263 | Codebook Loss: 1.2627
# Epoch [222/2000] | Total Loss: 612.7900 | Track Loss: 158.4191 | Map Loss: 453.0337 | Commitment Loss: 0.1216 | Codebook Loss: 1.2156
# Epoch [223/2000] | Total Loss: 608.1626 | Track Loss: 157.6994 | Map Loss: 449.1544 | Commitment Loss: 0.1190 | Codebook Loss: 1.1899
# Epoch [224/2000] | Total Loss: 603.2220 | Track Loss: 156.6651 | Map Loss: 445.2471 | Commitment Loss: 0.1191 | Codebook Loss: 1.1908
# Epoch [225/2000] | Total Loss: 597.9340 | Track Loss: 155.2976 | Map Loss: 441.3338 | Commitment Loss: 0.1184 | Codebook Loss: 1.1842
# Epoch [226/2000] | Total Loss: 592.7473 | Track Loss: 154.0299 | Map Loss: 437.4121 | Commitment Loss: 0.1187 | Codebook Loss: 1.1867
# Epoch [227/2000] | Total Loss: 587.7053 | Track Loss: 152.8939 | Map Loss: 433.5096 | Commitment Loss: 0.1183 | Codebook Loss: 1.1834
# Epoch [228/2000] | Total Loss: 582.5521 | Track Loss: 151.6135 | Map Loss: 429.6488 | Commitment Loss: 0.1173 | Codebook Loss: 1.1726
# Epoch [229/2000] | Total Loss: 577.2758 | Track Loss: 150.1694 | Map Loss: 425.8192 | Commitment Loss: 0.1170 | Codebook Loss: 1.1701
# Epoch [230/2000] | Total Loss: 572.2739 | Track Loss: 149.0050 | Map Loss: 421.9837 | Commitment Loss: 0.1168 | Codebook Loss: 1.1684
# Epoch [231/2000] | Total Loss: 567.1017 | Track Loss: 147.6937 | Map Loss: 418.1318 | Commitment Loss: 0.1160 | Codebook Loss: 1.1601
# Epoch [232/2000] | Total Loss: 561.7443 | Track Loss: 146.2000 | Map Loss: 414.2701 | Commitment Loss: 0.1158 | Codebook Loss: 1.1584
# Epoch [233/2000] | Total Loss: 556.5589 | Track Loss: 144.8942 | Map Loss: 410.4055 | Commitment Loss: 0.1145 | Codebook Loss: 1.1447
# Epoch [234/2000] | Total Loss: 551.4653 | Track Loss: 143.6838 | Map Loss: 406.5232 | Commitment Loss: 0.1144 | Codebook Loss: 1.1439
# Epoch [235/2000] | Total Loss: 546.2056 | Track Loss: 142.2836 | Map Loss: 402.6673 | Commitment Loss: 0.1141 | Codebook Loss: 1.1406
# Epoch [236/2000] | Total Loss: 540.9775 | Track Loss: 140.9175 | Map Loss: 398.8159 | Commitment Loss: 0.1131 | Codebook Loss: 1.1310
# Epoch [237/2000] | Total Loss: 536.1515 | Track Loss: 139.9501 | Map Loss: 394.9529 | Commitment Loss: 0.1135 | Codebook Loss: 1.1350
# Epoch [238/2000] | Total Loss: 530.9219 | Track Loss: 138.6213 | Map Loss: 391.0540 | Commitment Loss: 0.1133 | Codebook Loss: 1.1334
# Epoch [239/2000] | Total Loss: 525.8240 | Track Loss: 137.5065 | Map Loss: 387.0889 | Commitment Loss: 0.1117 | Codebook Loss: 1.1168
# Epoch [240/2000] | Total Loss: 520.0501 | Track Loss: 135.7483 | Map Loss: 383.0665 | Commitment Loss: 0.1123 | Codebook Loss: 1.1230
# Epoch [241/2000] | Total Loss: 515.8270 | Track Loss: 134.9198 | Map Loss: 379.6757 | Commitment Loss: 0.1120 | Codebook Loss: 1.1196
# Epoch [242/2000] | Total Loss: 509.5426 | Track Loss: 133.5292 | Map Loss: 374.7921 | Commitment Loss: 0.1110 | Codebook Loss: 1.1103
# Epoch [243/2000] | Total Loss: 504.0038 | Track Loss: 132.1838 | Map Loss: 370.5855 | Commitment Loss: 0.1122 | Codebook Loss: 1.1222
# Epoch [244/2000] | Total Loss: 498.3058 | Track Loss: 130.7118 | Map Loss: 366.3534 | Commitment Loss: 0.1128 | Codebook Loss: 1.1279
# Epoch [245/2000] | Total Loss: 492.7912 | Track Loss: 129.4389 | Map Loss: 362.0930 | Commitment Loss: 0.1145 | Codebook Loss: 1.1448
# Epoch [246/2000] | Total Loss: 487.2657 | Track Loss: 128.1767 | Map Loss: 357.8229 | Commitment Loss: 0.1151 | Codebook Loss: 1.1510
# Epoch [247/2000] | Total Loss: 481.3062 | Track Loss: 126.4968 | Map Loss: 353.5584 | Commitment Loss: 0.1137 | Codebook Loss: 1.1372
# Epoch [248/2000] | Total Loss: 475.8600 | Track Loss: 125.3460 | Map Loss: 349.2705 | Commitment Loss: 0.1131 | Codebook Loss: 1.1305
# Epoch [249/2000] | Total Loss: 470.0366 | Track Loss: 123.8260 | Map Loss: 344.9720 | Commitment Loss: 0.1126 | Codebook Loss: 1.1260
# Epoch [250/2000] | Total Loss: 464.2674 | Track Loss: 122.4017 | Map Loss: 340.6465 | Commitment Loss: 0.1108 | Codebook Loss: 1.1084
# Epoch [251/2000] | Total Loss: 458.4843 | Track Loss: 120.9663 | Map Loss: 336.2936 | Commitment Loss: 0.1113 | Codebook Loss: 1.1131
# Epoch [252/2000] | Total Loss: 452.6372 | Track Loss: 119.5205 | Map Loss: 331.9199 | Commitment Loss: 0.1088 | Codebook Loss: 1.0881
# Epoch [253/2000] | Total Loss: 446.7945 | Track Loss: 118.0851 | Map Loss: 327.5114 | Commitment Loss: 0.1089 | Codebook Loss: 1.0891
# Epoch [254/2000] | Total Loss: 440.9253 | Track Loss: 116.6506 | Map Loss: 323.0867 | Commitment Loss: 0.1080 | Codebook Loss: 1.0799
# Epoch [255/2000] | Total Loss: 435.0226 | Track Loss: 115.2270 | Map Loss: 318.6290 | Commitment Loss: 0.1061 | Codebook Loss: 1.0606
# Epoch [256/2000] | Total Loss: 429.0788 | Track Loss: 113.7649 | Map Loss: 314.1411 | Commitment Loss: 0.1066 | Codebook Loss: 1.0663
# Epoch [257/2000] | Total Loss: 423.8968 | Track Loss: 112.3323 | Map Loss: 310.3989 | Commitment Loss: 0.1060 | Codebook Loss: 1.0597
# Epoch [258/2000] | Total Loss: 417.1340 | Track Loss: 110.8880 | Map Loss: 305.0790 | Commitment Loss: 0.1061 | Codebook Loss: 1.0609
# Epoch [259/2000] | Total Loss: 411.8793 | Track Loss: 109.4332 | Map Loss: 301.2920 | Commitment Loss: 0.1049 | Codebook Loss: 1.0492
# Epoch [260/2000] | Total Loss: 405.0262 | Track Loss: 107.9685 | Map Loss: 295.9112 | Commitment Loss: 0.1042 | Codebook Loss: 1.0423
# Epoch [261/2000] | Total Loss: 398.9193 | Track Loss: 106.4987 | Map Loss: 291.2850 | Commitment Loss: 0.1032 | Codebook Loss: 1.0324
# Epoch [262/2000] | Total Loss: 392.7858 | Track Loss: 105.0050 | Map Loss: 286.6317 | Commitment Loss: 0.1045 | Codebook Loss: 1.0446
# Epoch [263/2000] | Total Loss: 386.6310 | Track Loss: 103.5332 | Map Loss: 281.9655 | Commitment Loss: 0.1029 | Codebook Loss: 1.0293
# Epoch [264/2000] | Total Loss: 380.4260 | Track Loss: 102.0230 | Map Loss: 277.2697 | Commitment Loss: 0.1030 | Codebook Loss: 1.0303
# Epoch [265/2000] | Total Loss: 374.1914 | Track Loss: 100.5092 | Map Loss: 272.5489 | Commitment Loss: 0.1030 | Codebook Loss: 1.0303
# Epoch [266/2000] | Total Loss: 367.9377 | Track Loss: 99.0156 | Map Loss: 267.8000 | Commitment Loss: 0.1020 | Codebook Loss: 1.0201
# Epoch [267/2000] | Total Loss: 361.6445 | Track Loss: 97.4708 | Map Loss: 263.0297 | Commitment Loss: 0.1040 | Codebook Loss: 1.0400
# Epoch [268/2000] | Total Loss: 355.3380 | Track Loss: 95.9723 | Map Loss: 258.2477 | Commitment Loss: 0.1016 | Codebook Loss: 1.0164
# Epoch [269/2000] | Total Loss: 348.9910 | Track Loss: 94.4152 | Map Loss: 253.4290 | Commitment Loss: 0.1043 | Codebook Loss: 1.0425
# Epoch [270/2000] | Total Loss: 343.3989 | Track Loss: 92.8815 | Map Loss: 249.4047 | Commitment Loss: 0.1011 | Codebook Loss: 1.0115
# Epoch [271/2000] | Total Loss: 336.2090 | Track Loss: 91.3282 | Map Loss: 243.7569 | Commitment Loss: 0.1022 | Codebook Loss: 1.0217
# Epoch [272/2000] | Total Loss: 329.7556 | Track Loss: 89.7775 | Map Loss: 238.8716 | Commitment Loss: 0.1006 | Codebook Loss: 1.0058
# Epoch [273/2000] | Total Loss: 323.2917 | Track Loss: 88.2224 | Map Loss: 233.9565 | Commitment Loss: 0.1012 | Codebook Loss: 1.0116
# Epoch [274/2000] | Total Loss: 317.5050 | Track Loss: 86.6508 | Map Loss: 229.7352 | Commitment Loss: 0.1017 | Codebook Loss: 1.0173
# Epoch [275/2000] | Total Loss: 310.2353 | Track Loss: 85.0786 | Map Loss: 224.0370 | Commitment Loss: 0.1018 | Codebook Loss: 1.0179
# Epoch [276/2000] | Total Loss: 303.6442 | Track Loss: 83.4955 | Map Loss: 219.0365 | Commitment Loss: 0.1011 | Codebook Loss: 1.0111
# Epoch [277/2000] | Total Loss: 297.0194 | Track Loss: 81.9076 | Map Loss: 214.0290 | Commitment Loss: 0.0984 | Codebook Loss: 0.9844
# Epoch [278/2000] | Total Loss: 290.3938 | Track Loss: 80.3105 | Map Loss: 208.9980 | Commitment Loss: 0.0987 | Codebook Loss: 0.9866
# Epoch [279/2000] | Total Loss: 284.6138 | Track Loss: 78.7395 | Map Loss: 204.7789 | Commitment Loss: 0.0996 | Codebook Loss: 0.9958
# Epoch [280/2000] | Total Loss: 277.1229 | Track Loss: 77.1635 | Map Loss: 198.8850 | Commitment Loss: 0.0977 | Codebook Loss: 0.9767
# Epoch [281/2000] | Total Loss: 271.2621 | Track Loss: 75.5197 | Map Loss: 194.6817 | Commitment Loss: 0.0964 | Codebook Loss: 0.9643
# Epoch [282/2000] | Total Loss: 263.6884 | Track Loss: 73.8730 | Map Loss: 188.7486 | Commitment Loss: 0.0970 | Codebook Loss: 0.9698
# Epoch [283/2000] | Total Loss: 256.9770 | Track Loss: 72.2601 | Map Loss: 183.6449 | Commitment Loss: 0.0975 | Codebook Loss: 0.9746
# Epoch [284/2000] | Total Loss: 251.0938 | Track Loss: 70.6572 | Map Loss: 179.3810 | Commitment Loss: 0.0960 | Codebook Loss: 0.9596
# Epoch [285/2000] | Total Loss: 243.4900 | Track Loss: 69.0468 | Map Loss: 173.3796 | Commitment Loss: 0.0967 | Codebook Loss: 0.9669
# Epoch [286/2000] | Total Loss: 236.6920 | Track Loss: 67.4032 | Map Loss: 168.2403 | Commitment Loss: 0.0953 | Codebook Loss: 0.9532
# Epoch [287/2000] | Total Loss: 229.8719 | Track Loss: 65.7349 | Map Loss: 163.0894 | Commitment Loss: 0.0952 | Codebook Loss: 0.9524
# Epoch [288/2000] | Total Loss: 223.0518 | Track Loss: 64.0895 | Map Loss: 157.9083 | Commitment Loss: 0.0958 | Codebook Loss: 0.9581
# Epoch [289/2000] | Total Loss: 216.2086 | Track Loss: 62.4604 | Map Loss: 152.7078 | Commitment Loss: 0.0946 | Codebook Loss: 0.9458
# Epoch [290/2000] | Total Loss: 209.3407 | Track Loss: 60.8128 | Map Loss: 147.4969 | Commitment Loss: 0.0937 | Codebook Loss: 0.9372
# Epoch [291/2000] | Total Loss: 202.4500 | Track Loss: 59.1370 | Map Loss: 142.2723 | Commitment Loss: 0.0946 | Codebook Loss: 0.9462
# Epoch [292/2000] | Total Loss: 195.4971 | Track Loss: 57.4596 | Map Loss: 137.0180 | Commitment Loss: 0.0927 | Codebook Loss: 0.9268
# Epoch [293/2000] | Total Loss: 188.5693 | Track Loss: 55.7951 | Map Loss: 131.7478 | Commitment Loss: 0.0933 | Codebook Loss: 0.9330
# Epoch [294/2000] | Total Loss: 182.5072 | Track Loss: 54.1310 | Map Loss: 127.3558 | Commitment Loss: 0.0928 | Codebook Loss: 0.9276
# Epoch [295/2000] | Total Loss: 174.5980 | Track Loss: 52.4366 | Map Loss: 121.1493 | Commitment Loss: 0.0920 | Codebook Loss: 0.9201
# Epoch [296/2000] | Total Loss: 168.4702 | Track Loss: 50.7391 | Map Loss: 116.7272 | Commitment Loss: 0.0913 | Codebook Loss: 0.9127
# Epoch [297/2000] | Total Loss: 160.5215 | Track Loss: 49.0479 | Map Loss: 110.4674 | Commitment Loss: 0.0915 | Codebook Loss: 0.9148
# Epoch [298/2000] | Total Loss: 153.4469 | Track Loss: 47.3539 | Map Loss: 105.0972 | Commitment Loss: 0.0905 | Codebook Loss: 0.9052
# Epoch [299/2000] | Total Loss: 147.2846 | Track Loss: 45.6409 | Map Loss: 100.6361 | Commitment Loss: 0.0916 | Codebook Loss: 0.9161
# Epoch [300/2000] | Total Loss: 139.2171 | Track Loss: 43.9204 | Map Loss: 94.3035 | Commitment Loss: 0.0903 | Codebook Loss: 0.9028
# Epoch [301/2000] | Total Loss: 133.0027 | Track Loss: 42.2027 | Map Loss: 89.7967 | Commitment Loss: 0.0912 | Codebook Loss: 0.9121
# Epoch [302/2000] | Total Loss: 124.8910 | Track Loss: 40.4837 | Map Loss: 83.4209 | Commitment Loss: 0.0897 | Codebook Loss: 0.8967
# Epoch [303/2000] | Total Loss: 117.7159 | Track Loss: 38.7525 | Map Loss: 77.9607 | Commitment Loss: 0.0912 | Codebook Loss: 0.9116
# Epoch [304/2000] | Total Loss: 110.4701 | Track Loss: 37.0107 | Map Loss: 72.4629 | Commitment Loss: 0.0906 | Codebook Loss: 0.9059
# Epoch [305/2000] | Total Loss: 104.1866 | Track Loss: 35.2702 | Map Loss: 67.9183 | Commitment Loss: 0.0907 | Codebook Loss: 0.9073
# Epoch [306/2000] | Total Loss: 95.9734 | Track Loss: 33.5270 | Map Loss: 61.4524 | Commitment Loss: 0.0904 | Codebook Loss: 0.9037
# Epoch [307/2000] | Total Loss: 88.6783 | Track Loss: 31.7750 | Map Loss: 55.9195 | Commitment Loss: 0.0894 | Codebook Loss: 0.8944
# Epoch [308/2000] | Total Loss: 81.3486 | Track Loss: 30.0110 | Map Loss: 50.3674 | Commitment Loss: 0.0882 | Codebook Loss: 0.8819
# Epoch [309/2000] | Total Loss: 74.0084 | Track Loss: 28.2421 | Map Loss: 44.7836 | Commitment Loss: 0.0893 | Codebook Loss: 0.8934
# Epoch [310/2000] | Total Loss: 66.6599 | Track Loss: 26.4731 | Map Loss: 39.2009 | Commitment Loss: 0.0896 | Codebook Loss: 0.8962
# Epoch [311/2000] | Total Loss: 60.2607 | Track Loss: 24.6975 | Map Loss: 34.5859 | Commitment Loss: 0.0888 | Codebook Loss: 0.8884
# Epoch [312/2000] | Total Loss: 52.0383 | Track Loss: 22.9170 | Map Loss: 28.1696 | Commitment Loss: 0.0865 | Codebook Loss: 0.8652
# Epoch [313/2000] | Total Loss: 46.3799 | Track Loss: 21.1155 | Map Loss: 24.3012 | Commitment Loss: 0.0876 | Codebook Loss: 0.8756
# Epoch [314/2000] | Total Loss: 40.0956 | Track Loss: 19.2639 | Map Loss: 19.8797 | Commitment Loss: 0.0865 | Codebook Loss: 0.8654
# Epoch [315/2000] | Total Loss: 35.9044 | Track Loss: 17.4200 | Map Loss: 17.5367 | Commitment Loss: 0.0862 | Codebook Loss: 0.8615
# Epoch [316/2000] | Total Loss: 34.6542 | Track Loss: 16.1746 | Map Loss: 17.5274 | Commitment Loss: 0.0866 | Codebook Loss: 0.8656
# Epoch [317/2000] | Total Loss: 32.8983 | Track Loss: 13.7052 | Map Loss: 18.2468 | Commitment Loss: 0.0860 | Codebook Loss: 0.8604
# Epoch [318/2000] | Total Loss: 34.1131 | Track Loss: 12.5656 | Map Loss: 20.6077 | Commitment Loss: 0.0854 | Codebook Loss: 0.8544
# Epoch [319/2000] | Total Loss: 34.8742 | Track Loss: 11.7493 | Map Loss: 22.1935 | Commitment Loss: 0.0847 | Codebook Loss: 0.8467
# Epoch [320/2000] | Total Loss: 33.2006 | Track Loss: 11.3470 | Map Loss: 20.9256 | Commitment Loss: 0.0844 | Codebook Loss: 0.8436
# Epoch [321/2000] | Total Loss: 33.2595 | Track Loss: 10.5420 | Map Loss: 21.7911 | Commitment Loss: 0.0842 | Codebook Loss: 0.8422
# Epoch [322/2000] | Total Loss: 31.9868 | Track Loss: 11.5889 | Map Loss: 19.4757 | Commitment Loss: 0.0838 | Codebook Loss: 0.8384
# Epoch [323/2000] | Total Loss: 35.7215 | Track Loss: 12.4405 | Map Loss: 22.3605 | Commitment Loss: 0.0837 | Codebook Loss: 0.8369
# Epoch [324/2000] | Total Loss: 31.9948 | Track Loss: 12.3185 | Map Loss: 18.7555 | Commitment Loss: 0.0837 | Codebook Loss: 0.8370
# Epoch [325/2000] | Total Loss: 33.4386 | Track Loss: 11.9404 | Map Loss: 20.5790 | Commitment Loss: 0.0836 | Codebook Loss: 0.8356
# Epoch [326/2000] | Total Loss: 30.9800 | Track Loss: 12.1224 | Map Loss: 17.9442 | Commitment Loss: 0.0830 | Codebook Loss: 0.8303
# Epoch [327/2000] | Total Loss: 31.7023 | Track Loss: 12.8535 | Map Loss: 17.9491 | Commitment Loss: 0.0818 | Codebook Loss: 0.8178
# Epoch [328/2000] | Total Loss: 30.5851 | Track Loss: 12.0660 | Map Loss: 17.6030 | Commitment Loss: 0.0833 | Codebook Loss: 0.8329
# Epoch [329/2000] | Total Loss: 30.1865 | Track Loss: 11.9031 | Map Loss: 17.3716 | Commitment Loss: 0.0829 | Codebook Loss: 0.8289
# Epoch [330/2000] | Total Loss: 31.3937 | Track Loss: 12.3393 | Map Loss: 18.1620 | Commitment Loss: 0.0811 | Codebook Loss: 0.8113
# Epoch [331/2000] | Total Loss: 30.4796 | Track Loss: 12.0962 | Map Loss: 17.4781 | Commitment Loss: 0.0823 | Codebook Loss: 0.8230
# Epoch [332/2000] | Total Loss: 30.4590 | Track Loss: 11.9941 | Map Loss: 17.5682 | Commitment Loss: 0.0815 | Codebook Loss: 0.8152
# Epoch [333/2000] | Total Loss: 30.5309 | Track Loss: 12.0747 | Map Loss: 17.5594 | Commitment Loss: 0.0815 | Codebook Loss: 0.8152
# Epoch [334/2000] | Total Loss: 29.4987 | Track Loss: 11.1233 | Map Loss: 17.4857 | Commitment Loss: 0.0809 | Codebook Loss: 0.8088
# Epoch [335/2000] | Total Loss: 29.8750 | Track Loss: 11.3282 | Map Loss: 17.6499 | Commitment Loss: 0.0815 | Codebook Loss: 0.8154
# Epoch [336/2000] | Total Loss: 30.0372 | Track Loss: 11.7157 | Map Loss: 17.4431 | Commitment Loss: 0.0798 | Codebook Loss: 0.7985
# Epoch [337/2000] | Total Loss: 29.5362 | Track Loss: 11.3320 | Map Loss: 17.3173 | Commitment Loss: 0.0806 | Codebook Loss: 0.8062
# Epoch [338/2000] | Total Loss: 29.1160 | Track Loss: 10.8549 | Map Loss: 17.3891 | Commitment Loss: 0.0793 | Codebook Loss: 0.7927
# Epoch [339/2000] | Total Loss: 28.9212 | Track Loss: 10.8152 | Map Loss: 17.2285 | Commitment Loss: 0.0798 | Codebook Loss: 0.7977
# Epoch [340/2000] | Total Loss: 29.3380 | Track Loss: 11.1521 | Map Loss: 17.3234 | Commitment Loss: 0.0784 | Codebook Loss: 0.7840
# Epoch [341/2000] | Total Loss: 28.8891 | Track Loss: 10.6789 | Map Loss: 17.3407 | Commitment Loss: 0.0790 | Codebook Loss: 0.7905
# Epoch [342/2000] | Total Loss: 28.8630 | Track Loss: 10.6795 | Map Loss: 17.3229 | Commitment Loss: 0.0782 | Codebook Loss: 0.7824
# Epoch [343/2000] | Total Loss: 29.5449 | Track Loss: 11.2925 | Map Loss: 17.3940 | Commitment Loss: 0.0780 | Codebook Loss: 0.7803
# Epoch [344/2000] | Total Loss: 29.4260 | Track Loss: 11.2694 | Map Loss: 17.2882 | Commitment Loss: 0.0789 | Codebook Loss: 0.7894
# Epoch [345/2000] | Total Loss: 29.0654 | Track Loss: 10.9091 | Map Loss: 17.3003 | Commitment Loss: 0.0778 | Codebook Loss: 0.7782
# Epoch [346/2000] | Total Loss: 29.1662 | Track Loss: 11.1150 | Map Loss: 17.2055 | Commitment Loss: 0.0769 | Codebook Loss: 0.7688
# Epoch [347/2000] | Total Loss: 28.7596 | Track Loss: 10.6564 | Map Loss: 17.2394 | Commitment Loss: 0.0785 | Codebook Loss: 0.7853
# Epoch [348/2000] | Total Loss: 28.7990 | Track Loss: 10.8025 | Map Loss: 17.1659 | Commitment Loss: 0.0755 | Codebook Loss: 0.7551
# Epoch [349/2000] | Total Loss: 29.0157 | Track Loss: 10.9539 | Map Loss: 17.2379 | Commitment Loss: 0.0749 | Codebook Loss: 0.7491
# Epoch [350/2000] | Total Loss: 28.4354 | Track Loss: 10.4008 | Map Loss: 17.2075 | Commitment Loss: 0.0752 | Codebook Loss: 0.7519
# Epoch [351/2000] | Total Loss: 28.5746 | Track Loss: 10.4827 | Map Loss: 17.2683 | Commitment Loss: 0.0749 | Codebook Loss: 0.7487
# Epoch [352/2000] | Total Loss: 28.6367 | Track Loss: 10.6094 | Map Loss: 17.2079 | Commitment Loss: 0.0745 | Codebook Loss: 0.7449
# Epoch [353/2000] | Total Loss: 28.7005 | Track Loss: 10.6542 | Map Loss: 17.2313 | Commitment Loss: 0.0741 | Codebook Loss: 0.7409
# Epoch [354/2000] | Total Loss: 28.6263 | Track Loss: 10.6161 | Map Loss: 17.1877 | Commitment Loss: 0.0748 | Codebook Loss: 0.7478
# Epoch [355/2000] | Total Loss: 28.3875 | Track Loss: 10.2840 | Map Loss: 17.2438 | Commitment Loss: 0.0782 | Codebook Loss: 0.7816
# Epoch [356/2000] | Total Loss: 28.4182 | Track Loss: 10.4061 | Map Loss: 17.1586 | Commitment Loss: 0.0776 | Codebook Loss: 0.7758
# ...
# Epoch [468/2000] | Total Loss: 73.2535 | Track Loss: 9.8411 | Map Loss: 62.1656 | Commitment Loss: 0.1133 | Codebook Loss: 1.1334
# Epoch [469/2000] | Total Loss: 64.5515 | Track Loss: 10.2205 | Map Loss: 53.0868 | Commitment Loss: 0.1131 | Codebook Loss: 1.1311
# Epoch [470/2000] | Total Loss: 147.5168 | Track Loss: 10.5055 | Map Loss: 135.7605 | Commitment Loss: 0.1137 | Codebook Loss: 1.1372
# Epoch [471/2000] | Total Loss: 47.2314 | Track Loss: 10.8078 | Map Loss: 35.1751 | Commitment Loss: 0.1135 | Codebook Loss: 1.1350
# Epoch [472/2000] | Total Loss: 31.1169 | Track Loss: 10.8116 | Map Loss: 19.0584 | Commitment Loss: 0.1134 | Codebook Loss: 1.1335
# Epoch [473/2000] | Total Loss: 29.5502 | Track Loss: 10.7288 | Map Loss: 17.5830 | Commitment Loss: 0.1126 | Codebook Loss: 1.1259
# Epoch [474/2000] | Total Loss: 29.0629 | Track Loss: 10.3758 | Map Loss: 17.4565 | Commitment Loss: 0.1119 | Codebook Loss: 1.1187
# Epoch [475/2000] | Total Loss: 28.4222 | Track Loss: 9.8315 | Map Loss: 17.3801 | Commitment Loss: 0.1101 | Codebook Loss: 1.1005
# Epoch [476/2000] | Total Loss: 28.6124 | Track Loss: 10.0842 | Map Loss: 17.3275 | Commitment Loss: 0.1091 | Codebook Loss: 1.0915
# Epoch [477/2000] | Total Loss: 28.5773 | Track Loss: 9.9578 | Map Loss: 17.4759 | Commitment Loss: 0.1040 | Codebook Loss: 1.0397
# Epoch [478/2000] | Total Loss: 30.2852 | Track Loss: 9.9170 | Map Loss: 19.2305 | Commitment Loss: 0.1034 | Codebook Loss: 1.0343
# Epoch [479/2000] | Total Loss: 33.2067 | Track Loss: 9.9929 | Map Loss: 22.0836 | Commitment Loss: 0.1027 | Codebook Loss: 1.0274
# Epoch [480/2000] | Total Loss: 47.6218 | Track Loss: 9.8723 | Map Loss: 36.6342 | Commitment Loss: 0.1014 | Codebook Loss: 1.0138
# Epoch [481/2000] | Total Loss: 33.8894 | Track Loss: 9.9321 | Map Loss: 22.8503 | Commitment Loss: 0.1006 | Codebook Loss: 1.0063
# Epoch [482/2000] | Total Loss: 30.8070 | Track Loss: 9.9977 | Map Loss: 19.7078 | Commitment Loss: 0.1001 | Codebook Loss: 1.0013
# Epoch [483/2000] | Total Loss: 30.1768 | Track Loss: 9.7710 | Map Loss: 19.3152 | Commitment Loss: 0.0991 | Codebook Loss: 0.9915
# Epoch [484/2000] | Total Loss: 77.0947 | Track Loss: 10.1733 | Map Loss: 65.8416 | Commitment Loss: 0.0982 | Codebook Loss: 0.9817
# Epoch [485/2000] | Total Loss: 81.7655 | Track Loss: 10.0477 | Map Loss: 70.6462 | Commitment Loss: 0.0974 | Codebook Loss: 0.9742
# Epoch [486/2000] | Total Loss: 291.8853 | Track Loss: 10.0579 | Map Loss: 280.7721 | Commitment Loss: 0.0959 | Codebook Loss: 0.9594
# Epoch [487/2000] | Total Loss: 301.1694 | Track Loss: 10.3898 | Map Loss: 289.7150 | Commitment Loss: 0.0968 | Codebook Loss: 0.9678
# Epoch [488/2000] | Total Loss: 1197.2169 | Track Loss: 10.3019 | Map Loss: 1185.7457 | Commitment Loss: 0.1063 | Codebook Loss: 1.0630
# Epoch [489/2000] | Total Loss: 1348.8680 | Track Loss: 10.0409 | Map Loss: 1337.6581 | Commitment Loss: 0.1063 | Codebook Loss: 1.0628
# Epoch [490/2000] | Total Loss: 1359.0704 | Track Loss: 9.9932 | Map Loss: 1347.9122 | Commitment Loss: 0.1059 | Codebook Loss: 1.0591
# Epoch [491/2000] | Total Loss: 1402.5392 | Track Loss: 10.0775 | Map Loss: 1391.3580 | Commitment Loss: 0.1003 | Codebook Loss: 1.0033
# Epoch [492/2000] | Total Loss: 1390.6631 | Track Loss: 10.2564 | Map Loss: 1379.3101 | Commitment Loss: 0.0997 | Codebook Loss: 0.9968
# Epoch [493/2000] | Total Loss: 1085.4004 | Track Loss: 10.4822 | Map Loss: 1073.8185 | Commitment Loss: 0.1000 | Codebook Loss: 0.9997
# Epoch [494/2000] | Total Loss: 298.8913 | Track Loss: 10.7090 | Map Loss: 287.0889 | Commitment Loss: 0.0994 | Codebook Loss: 0.9940
# Epoch [495/2000] | Total Loss: 258.4846 | Track Loss: 10.8825 | Map Loss: 246.5053 | Commitment Loss: 0.0997 | Codebook Loss: 0.9971
# Epoch [496/2000] | Total Loss: 276.4629 | Track Loss: 10.5635 | Map Loss: 264.8011 | Commitment Loss: 0.0998 | Codebook Loss: 0.9985
# Epoch [497/2000] | Total Loss: 267.1545 | Track Loss: 10.4968 | Map Loss: 255.5562 | Commitment Loss: 0.1001 | Codebook Loss: 1.0014
# Epoch [498/2000] | Total Loss: 241.4027 | Track Loss: 9.9077 | Map Loss: 230.3936 | Commitment Loss: 0.1001 | Codebook Loss: 1.0013
# Epoch [499/2000] | Total Loss: 229.8992 | Track Loss: 10.3707 | Map Loss: 218.4221 | Commitment Loss: 0.1006 | Codebook Loss: 1.0058
# Epoch [500/2000] | Total Loss: 254.7539 | Track Loss: 10.7228 | Map Loss: 242.9187 | Commitment Loss: 0.1011 | Codebook Loss: 1.0114
# Epoch [501/2000] | Total Loss: 264.2464 | Track Loss: 10.4546 | Map Loss: 252.6854 | Commitment Loss: 0.1006 | Codebook Loss: 1.0058
# Epoch [502/2000] | Total Loss: 245.5061 | Track Loss: 10.1967 | Map Loss: 234.1825 | Commitment Loss: 0.1025 | Codebook Loss: 1.0246
# Epoch [503/2000] | Total Loss: 1103.2231 | Track Loss: 10.1861 | Map Loss: 1091.9319 | Commitment Loss: 0.1005 | Codebook Loss: 1.0046
# Epoch [504/2000] | Total Loss: 1118.4836 | Track Loss: 10.4162 | Map Loss: 1106.9486 | Commitment Loss: 0.1017 | Codebook Loss: 1.0171
# Epoch [505/2000] | Total Loss: 1083.3861 | Track Loss: 10.3259 | Map Loss: 1071.9406 | Commitment Loss: 0.1018 | Codebook Loss: 1.0178
# Epoch [506/2000] | Total Loss: 1058.8079 | Track Loss: 10.2168 | Map Loss: 1047.4670 | Commitment Loss: 0.1022 | Codebook Loss: 1.0218
# Epoch [507/2000] | Total Loss: 1045.2100 | Track Loss: 10.0130 | Map Loss: 1034.0784 | Commitment Loss: 0.1017 | Codebook Loss: 1.0168
# Epoch [508/2000] | Total Loss: 1021.3448 | Track Loss: 10.0827 | Map Loss: 1010.1472 | Commitment Loss: 0.1014 | Codebook Loss: 1.0135
# Epoch [509/2000] | Total Loss: 973.5400 | Track Loss: 10.1532 | Map Loss: 962.2791 | Commitment Loss: 0.1007 | Codebook Loss: 1.0071
# Epoch [510/2000] | Total Loss: 1078.3131 | Track Loss: 10.3088 | Map Loss: 1066.8942 | Commitment Loss: 0.1009 | Codebook Loss: 1.0093
# Epoch [511/2000] | Total Loss: 970.5852 | Track Loss: 10.4036 | Map Loss: 959.0674 | Commitment Loss: 0.1013 | Codebook Loss: 1.0129
# Epoch [512/2000] | Total Loss: 611.8128 | Track Loss: 10.4659 | Map Loss: 600.2285 | Commitment Loss: 0.1017 | Codebook Loss: 1.0168
# Epoch [513/2000] | Total Loss: 274.5829 | Track Loss: 10.5082 | Map Loss: 262.9559 | Commitment Loss: 0.1017 | Codebook Loss: 1.0171
# Epoch [514/2000] | Total Loss: 177.3878 | Track Loss: 10.4970 | Map Loss: 165.7685 | Commitment Loss: 0.1020 | Codebook Loss: 1.0202
# Epoch [515/2000] | Total Loss: 142.6512 | Track Loss: 10.2088 | Map Loss: 131.3174 | Commitment Loss: 0.1023 | Codebook Loss: 1.0227
# Epoch [516/2000] | Total Loss: 51.7211 | Track Loss: 9.8772 | Map Loss: 40.7213 | Commitment Loss: 0.1020 | Codebook Loss: 1.0205
# Epoch [517/2000] | Total Loss: 43.3910 | Track Loss: 10.1687 | Map Loss: 32.0963 | Commitment Loss: 0.1024 | Codebook Loss: 1.0237
# Epoch [518/2000] | Total Loss: 29.6565 | Track Loss: 10.1205 | Map Loss: 18.4078 | Commitment Loss: 0.1026 | Codebook Loss: 1.0256
# Epoch [519/2000] | Total Loss: 28.6129 | Track Loss: 10.1040 | Map Loss: 17.3637 | Commitment Loss: 0.1041 | Codebook Loss: 1.0410
# Epoch [520/2000] | Total Loss: 28.9644 | Track Loss: 9.8898 | Map Loss: 17.8901 | Commitment Loss: 0.1077 | Codebook Loss: 1.0768
# Epoch [521/2000] | Total Loss: 32.0926 | Track Loss: 10.0470 | Map Loss: 20.8710 | Commitment Loss: 0.1068 | Codebook Loss: 1.0678
# Epoch [522/2000] | Total Loss: 55.8053 | Track Loss: 9.8630 | Map Loss: 44.7695 | Commitment Loss: 0.1066 | Codebook Loss: 1.0662
# Epoch [523/2000] | Total Loss: 53.9133 | Track Loss: 9.9570 | Map Loss: 42.7798 | Commitment Loss: 0.1070 | Codebook Loss: 1.0696
# Epoch [524/2000] | Total Loss: 36.4339 | Track Loss: 10.0674 | Map Loss: 25.1935 | Commitment Loss: 0.1066 | Codebook Loss: 1.0664
# Epoch [525/2000] | Total Loss: 34.3480 | Track Loss: 9.8427 | Map Loss: 23.3314 | Commitment Loss: 0.1067 | Codebook Loss: 1.0672
# Epoch [526/2000] | Total Loss: 32.2201 | Track Loss: 10.1129 | Map Loss: 20.9389 | Commitment Loss: 0.1062 | Codebook Loss: 1.0621
# Epoch [527/2000] | Total Loss: 31.4083 | Track Loss: 10.1126 | Map Loss: 20.1285 | Commitment Loss: 0.1061 | Codebook Loss: 1.0612
# Epoch [528/2000] | Total Loss: 31.3583 | Track Loss: 9.9812 | Map Loss: 20.2717 | Commitment Loss: 0.1005 | Codebook Loss: 1.0049
# Epoch [529/2000] | Total Loss: 36.6092 | Track Loss: 10.0236 | Map Loss: 25.4782 | Commitment Loss: 0.1007 | Codebook Loss: 1.0068
# Epoch [530/2000] | Total Loss: 33.1538 | Track Loss: 10.1888 | Map Loss: 21.8588 | Commitment Loss: 0.1006 | Codebook Loss: 1.0056
# Epoch [531/2000] | Total Loss: 88.3765 | Track Loss: 10.0346 | Map Loss: 77.2256 | Commitment Loss: 0.1015 | Codebook Loss: 1.0149
# Epoch [532/2000] | Total Loss: 81.2940 | Track Loss: 9.7955 | Map Loss: 70.3852 | Commitment Loss: 0.1012 | Codebook Loss: 1.0121
# Epoch [533/2000] | Total Loss: 178.9390 | Track Loss: 10.0606 | Map Loss: 167.7423 | Commitment Loss: 0.1033 | Codebook Loss: 1.0329
# Epoch [534/2000] | Total Loss: 76.4834 | Track Loss: 10.4194 | Map Loss: 64.9358 | Commitment Loss: 0.1026 | Codebook Loss: 1.0256
# Epoch [535/2000] | Total Loss: 37.8856 | Track Loss: 10.5838 | Map Loss: 26.1672 | Commitment Loss: 0.1032 | Codebook Loss: 1.0315
# Epoch [536/2000] | Total Loss: 32.1521 | Track Loss: 10.3790 | Map Loss: 20.6442 | Commitment Loss: 0.1026 | Codebook Loss: 1.0262
# Epoch [537/2000] | Total Loss: 31.6272 | Track Loss: 10.0951 | Map Loss: 20.4023 | Commitment Loss: 0.1027 | Codebook Loss: 1.0270
# Epoch [538/2000] | Total Loss: 34.5359 | Track Loss: 10.1328 | Map Loss: 23.2736 | Commitment Loss: 0.1027 | Codebook Loss: 1.0268
# Epoch [539/2000] | Total Loss: 29.7760 | Track Loss: 10.3408 | Map Loss: 18.3087 | Commitment Loss: 0.1024 | Codebook Loss: 1.0241
# Epoch [540/2000] | Total Loss: 36.2691 | Track Loss: 10.2389 | Map Loss: 24.9084 | Commitment Loss: 0.1020 | Codebook Loss: 1.0198
# Epoch [541/2000] | Total Loss: 32.9354 | Track Loss: 9.9960 | Map Loss: 21.8167 | Commitment Loss: 0.1021 | Codebook Loss: 1.0206
# Epoch [542/2000] | Total Loss: 32.9927 | Track Loss: 9.9935 | Map Loss: 21.8714 | Commitment Loss: 0.1025 | Codebook Loss: 1.0253
# Epoch [543/2000] | Total Loss: 32.1775 | Track Loss: 10.1895 | Map Loss: 20.8631 | Commitment Loss: 0.1023 | Codebook Loss: 1.0225
# Epoch [544/2000] | Total Loss: 32.3046 | Track Loss: 9.9686 | Map Loss: 21.1991 | Commitment Loss: 0.1034 | Codebook Loss: 1.0336
# Epoch [545/2000] | Total Loss: 35.4978 | Track Loss: 9.9618 | Map Loss: 24.4065 | Commitment Loss: 0.1027 | Codebook Loss: 1.0268
# Epoch [546/2000] | Total Loss: 34.3243 | Track Loss: 10.0864 | Map Loss: 23.1192 | Commitment Loss: 0.1017 | Codebook Loss: 1.0170
# Epoch [547/2000] | Total Loss: 34.1982 | Track Loss: 9.9731 | Map Loss: 23.1010 | Commitment Loss: 0.1022 | Codebook Loss: 1.0219
# Epoch [548/2000] | Total Loss: 37.0704 | Track Loss: 9.8223 | Map Loss: 26.1259 | Commitment Loss: 0.1020 | Codebook Loss: 1.0202
# Epoch [549/2000] | Total Loss: 37.7378 | Track Loss: 9.9606 | Map Loss: 26.6846 | Commitment Loss: 0.0993 | Codebook Loss: 0.9932
# Epoch [550/2000] | Total Loss: 32.1352 | Track Loss: 9.8788 | Map Loss: 21.1639 | Commitment Loss: 0.0993 | Codebook Loss: 0.9931
# Epoch [551/2000] | Total Loss: 32.3118 | Track Loss: 9.8893 | Map Loss: 21.3301 | Commitment Loss: 0.0993 | Codebook Loss: 0.9931
# Epoch [552/2000] | Total Loss: 37.3097 | Track Loss: 9.9042 | Map Loss: 26.3231 | Commitment Loss: 0.0984 | Codebook Loss: 0.9840
# Epoch [553/2000] | Total Loss: 31.2532 | Track Loss: 9.8351 | Map Loss: 20.3406 | Commitment Loss: 0.0979 | Codebook Loss: 0.9794
# Epoch [554/2000] | Total Loss: 33.4119 | Track Loss: 9.8613 | Map Loss: 22.4695 | Commitment Loss: 0.0983 | Codebook Loss: 0.9828
# Epoch [555/2000] | Total Loss: 31.1205 | Track Loss: 9.8700 | Map Loss: 20.1416 | Commitment Loss: 0.1008 | Codebook Loss: 1.0081
# Epoch [556/2000] | Total Loss: 35.4417 | Track Loss: 9.8838 | Map Loss: 24.4528 | Commitment Loss: 0.1005 | Codebook Loss: 1.0046
# Epoch [557/2000] | Total Loss: 30.3139 | Track Loss: 9.8529 | Map Loss: 19.3588 | Commitment Loss: 0.1002 | Codebook Loss: 1.0020
# Epoch [558/2000] | Total Loss: 29.2108 | Track Loss: 9.8740 | Map Loss: 18.2349 | Commitment Loss: 0.1002 | Codebook Loss: 1.0017
# Epoch [559/2000] | Total Loss: 29.1027 | Track Loss: 9.9204 | Map Loss: 18.0808 | Commitment Loss: 0.1001 | Codebook Loss: 1.0013
# Epoch [560/2000] | Total Loss: 29.2625 | Track Loss: 9.9340 | Map Loss: 18.2294 | Commitment Loss: 0.0999 | Codebook Loss: 0.9992
# Epoch [561/2000] | Total Loss: 29.2958 | Track Loss: 9.8106 | Map Loss: 18.3902 | Commitment Loss: 0.0995 | Codebook Loss: 0.9955
# Epoch [562/2000] | Total Loss: 30.0466 | Track Loss: 9.9082 | Map Loss: 19.0562 | Commitment Loss: 0.0984 | Codebook Loss: 0.9839
# Epoch [563/2000] | Total Loss: 28.9759 | Track Loss: 9.9519 | Map Loss: 17.9369 | Commitment Loss: 0.0988 | Codebook Loss: 0.9882
# Epoch [564/2000] | Total Loss: 28.5093 | Track Loss: 9.7947 | Map Loss: 17.6327 | Commitment Loss: 0.0983 | Codebook Loss: 0.9834
# Epoch [565/2000] | Total Loss: 28.8631 | Track Loss: 10.1912 | Map Loss: 17.6299 | Commitment Loss: 0.0947 | Codebook Loss: 0.9473
# Epoch [566/2000] | Total Loss: 29.1547 | Track Loss: 10.2978 | Map Loss: 17.8234 | Commitment Loss: 0.0939 | Codebook Loss: 0.9395
# Epoch [567/2000] | Total Loss: 29.6540 | Track Loss: 10.0643 | Map Loss: 18.5585 | Commitment Loss: 0.0937 | Codebook Loss: 0.9374
# Epoch [568/2000] | Total Loss: 31.5301 | Track Loss: 9.9758 | Map Loss: 20.5224 | Commitment Loss: 0.0938 | Codebook Loss: 0.9381
# Epoch [569/2000] | Total Loss: 30.8198 | Track Loss: 10.0395 | Map Loss: 19.7535 | Commitment Loss: 0.0933 | Codebook Loss: 0.9335
# Epoch [570/2000] | Total Loss: 37.4971 | Track Loss: 10.0274 | Map Loss: 26.4054 | Commitment Loss: 0.0968 | Codebook Loss: 0.9676
# Epoch [571/2000] | Total Loss: 32.5849 | Track Loss: 9.9362 | Map Loss: 21.5875 | Commitment Loss: 0.0965 | Codebook Loss: 0.9647
# Epoch [572/2000] | Total Loss: 36.4453 | Track Loss: 9.9440 | Map Loss: 25.4394 | Commitment Loss: 0.0965 | Codebook Loss: 0.9653
# Epoch [573/2000] | Total Loss: 35.4578 | Track Loss: 10.0630 | Map Loss: 24.3439 | Commitment Loss: 0.0955 | Codebook Loss: 0.9554
# Epoch [574/2000] | Total Loss: 34.3841 | Track Loss: 9.8274 | Map Loss: 23.5053 | Commitment Loss: 0.0956 | Codebook Loss: 0.9558
# Epoch [575/2000] | Total Loss: 33.5928 | Track Loss: 10.0934 | Map Loss: 22.4474 | Commitment Loss: 0.0956 | Codebook Loss: 0.9563
# Epoch [576/2000] | Total Loss: 31.5846 | Track Loss: 10.1064 | Map Loss: 20.4219 | Commitment Loss: 0.0960 | Codebook Loss: 0.9602
# Epoch [577/2000] | Total Loss: 31.8035 | Track Loss: 10.0097 | Map Loss: 20.7490 | Commitment Loss: 0.0950 | Codebook Loss: 0.9498
# Epoch [578/2000] | Total Loss: 59.7534 | Track Loss: 10.0732 | Map Loss: 48.6824 | Commitment Loss: 0.0907 | Codebook Loss: 0.9071
# Epoch [579/2000] | Total Loss: 44.9689 | Track Loss: 10.0746 | Map Loss: 33.9005 | Commitment Loss: 0.0903 | Codebook Loss: 0.9034
# Epoch [580/2000] | Total Loss: 49.9252 | Track Loss: 9.9722 | Map Loss: 38.9661 | Commitment Loss: 0.0897 | Codebook Loss: 0.8972
# Epoch [581/2000] | Total Loss: 43.8274 | Track Loss: 9.8841 | Map Loss: 32.9595 | Commitment Loss: 0.0894 | Codebook Loss: 0.8943
# Epoch [582/2000] | Total Loss: 37.2539 | Track Loss: 10.0251 | Map Loss: 26.2015 | Commitment Loss: 0.0934 | Codebook Loss: 0.9339
# Epoch [583/2000] | Total Loss: 29.2313 | Track Loss: 9.9047 | Map Loss: 18.3003 | Commitment Loss: 0.0933 | Codebook Loss: 0.9331
# Epoch [584/2000] | Total Loss: 28.4789 | Track Loss: 9.9642 | Map Loss: 17.4884 | Commitment Loss: 0.0933 | Codebook Loss: 0.9330
# Epoch [585/2000] | Total Loss: 28.3243 | Track Loss: 9.9701 | Map Loss: 17.3286 | Commitment Loss: 0.0932 | Codebook Loss: 0.9323
# Epoch [586/2000] | Total Loss: 29.1988 | Track Loss: 9.8983 | Map Loss: 18.2795 | Commitment Loss: 0.0928 | Codebook Loss: 0.9281
# Epoch [587/2000] | Total Loss: 28.4154 | Track Loss: 9.9334 | Map Loss: 17.4697 | Commitment Loss: 0.0920 | Codebook Loss: 0.9203
# Epoch [588/2000] | Total Loss: 28.3795 | Track Loss: 9.9618 | Map Loss: 17.4039 | Commitment Loss: 0.0922 | Codebook Loss: 0.9217
